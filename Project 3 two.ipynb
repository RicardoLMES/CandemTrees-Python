# %%
import pandas as pd

# %% [markdown]
# ## Task 2: Load Data and Perform Initial Exploration

# %% [markdown]
# ### 2.1 Trees
# The file `"camden_trees.xlsx"` is an Excel file, so we use the `read_excel()` function.

# %%
# Create a Pandas dataframe called trees that contains the contents of the Excel file
trees = pd.read_excel("camden_trees.xlsx")

# %% [markdown]
# We can now inspect the first few rows using `head()`.  By default, `head()` displays the first 5 rows.

# %%
# Display the first few rows
trees.head(10)
# Out:
#   Identifier  Number Of Trees                   Site Name Contract Area  \
# 0   00060053              1.0    Russell Nurseries Estate       Housing
# 1   00057855              1.0           BRECKNOCK JMI (E)     Education
# 2   00059953              1.0  Estate 51 Ravenshaw Street       Housing
# 3   00059915              1.0           ROSARY RC JMI (E)     Education
# 4   00010762              1.0          Holly Lodge Estate       Housing
# 5   00007523              1.0          Westcroft Estate 1       Housing
# 6   00041657              1.0          Westcroft Estate 4       Housing
# 7   00060359              1.0        TOTTENHAM COURT ROAD      Highways
# 8   00058880              1.0                    YORK WAY      Highways
# 9   00057919              1.0    Weedington Road Estate 2       Housing
#
#                              Scientific Name Inspection Date  \
# 0                            Vacant Tree Pit             NaT
# 1                            Vacant Tree Pit      2019-07-17
# 2                               Ficus carica             NaT
# 3                        Betula jacquemontii             NaT
# 4                       Ilex x altaclarensis      2017-06-14
# 5                             Betula pendula      2018-08-06
# 6                             Betula pendula      2018-08-06
# 7  Vacant Tree Pit (planned: Acer campestre)             NaT
# 8                            Corylus colurna      2019-10-23
# 9                         Mespilus germanica             NaT
#
#   Inspection Due Date  Height In Metres  Spread In Metres  \
# 0                 NaN               NaN               NaN
# 1           2022/2023               NaN               NaN
# 2                 NaN               5.0               4.0
# 3                 NaN               4.0               1.0
# 4           2020/2021              14.0               6.0
# 5           2021/2022               9.0               7.0
# 6           2021/2022               4.0               1.0
# 7                 NaN               NaN               NaN
# 8           2022/2023               0.0               0.0
# 9                 NaN               2.0               1.5
#
#    Diameter In Centimetres At Breast Height  Ward Code       Ward Name  \
# 0                                       NaN  E05000135  Hampstead Town
# 1                                       NaN  E05000131      Cantelowes
# 2                                      10.0        NaN             NaN
# 3                                       6.0  E05000135  Hampstead Town
# 4                                      26.0  E05000137        Highgate
# 5                                      29.0        NaN             NaN
# 6                                       5.0        NaN             NaN
# 7                                       NaN        NaN             NaN
# 8                                       0.0        NaN             NaN
# 9                                       4.0  E05000134      Gospel Oak
#
#    Easting  Northing  Longitude   Latitude                Location
# 0   527305    185240  -0.165240  51.551693   (51.551693, -0.16524)
# 1   529923    184782  -0.127681  51.546984  (51.546984, -0.127681)
# 2        0         0        NaN        NaN                     NaN
# 3   527249    185261  -0.166051  51.551901  (51.551901, -0.166051)
# 4   528414    186770  -0.148704  51.565198  (51.565198, -0.148704)
# 5   524253    185982  -0.208975  51.559049  (51.559049, -0.208975)
# 6   524253    185823  -0.209029  51.557613  (51.557613, -0.209029)
# 7        0         0        NaN        NaN                     NaN
# 8   530336    183342  -0.122259  51.533953  (51.533953, -0.122259)
# 9   528174    185268  -0.152705  51.551755  (51.551755, -0.152705)

# %% [markdown]
# It's good to understand the size of the dataset we are dealing with.  The `shape` property does this for us.

# %%
# Get the number of rows and columns
trees.shape
# Out:
# (23444, 17)

# %% [markdown]
# If there are lots of columns we can't always see all of them in the `head()` list above.  We can use the `columns` property to get a full list:

# %%
# Get a list of all the columns in the dataframe
trees.columns
# Out:
# Index(['Identifier', 'Number Of Trees', 'Site Name', 'Contract Area',
#        'Scientific Name', 'Inspection Date', 'Inspection Due Date',
#        'Height In Metres', 'Spread In Metres',
#        'Diameter In Centimetres At Breast Height', 'Ward Code', 'Ward Name',
#        'Easting', 'Northing', 'Longitude', 'Latitude', 'Location'],
#       dtype='object')

# %% [markdown]
# In order to process the data properly, we should understand the data type for each column.  Pandas attempts to work this out for us, but sometimes we need to give it a bit of a hand.  We can use the `dtypes` property to list the data types.  Note that `object` is Pandas way of saying `string`, i.e. a text data type.

# %%
# List the data types of each column
trees.dtypes
# Out:
# Identifier                                          object
# Number Of Trees                                    float64
# Site Name                                           object
# Contract Area                                       object
# Scientific Name                                     object
# Inspection Date                             datetime64[ns]
# Inspection Due Date                                 object
# Height In Metres                                   float64
# Spread In Metres                                   float64
# Diameter In Centimetres At Breast Height           float64
# Ward Code                                           object
# Ward Name                                           object
# Easting                                              int64
# Northing                                             int64
# Longitude                                          float64
# Latitude                                           float64
# Location                                            object
# dtype: object

# %% [markdown]
# ### 2.2 Environmental
# The file `"camden_trees_environmental.csv"` is a csv file.  Use the appropriate function to load it into a Pandas DataFrame.

# %%
# Create a Pandas dataframe called trees that contains the contents of the csv file
trees_cvs_file = pd.read_csv("camden_trees_environmental.csv")

# %%
# Display the first few rows
trees_cvs_file.head()
# Out:
#   Identifier     Maturity Physiological Condition Tree Set To Be Removed  \
# 0   00055125     Juvenile                    Good                     No
# 1   00059429  Middle aged                    Fair                     No
# 2   00018254       Mature                    Fair                     No
# 3   00027155       Mature                    Fair                     No
# 4   00041326     Juvenile                    Good                     No
#
#   Removal Reason  Capital Asset Value For Amenity Trees  \
# 0            NaN                                 115.07
# 1            NaN                                7518.08
# 2            NaN                               20419.63
# 3            NaN                               21447.74
# 4            NaN                                 524.30
#
#    Carbon Storage In Kilograms  \
# 0                          1.6
# 1                          NaN
# 2                        426.4
# 3                        448.3
# 4                          9.9
#
#    Gross Carbon Sequestration Per Year In Kilograms  \
# 0                                               0.5
# 1                                               NaN
# 2                                               8.8
# 3                                               9.6
# 4                                               1.4
#
#    Pollution Removal Per Year In Grams
# 0                                  5.7
# 1                                  NaN
# 2                                215.2
# 3                                379.1
# 4                                 12.8

# %%
# Get the number of rows and columns
# TODO
trees_cvs_file.shape
# Out:
# (23415, 9)

# %%
# Get a list of all the columns in the dataframe
trees_cvs_file.columns
# Out:
# Index(['Identifier', 'Maturity', 'Physiological Condition',
#        'Tree Set To Be Removed', 'Removal Reason',
#        'Capital Asset Value For Amenity Trees', 'Carbon Storage In Kilograms',
#        'Gross Carbon Sequestration Per Year In Kilograms',
#        'Pollution Removal Per Year In Grams'],
#       dtype='object')

# %%
# List the data types of each column
trees_cvs_file.dtypes
# Out:
# Identifier                                           object
# Maturity                                             object
# Physiological Condition                              object
# Tree Set To Be Removed                               object
# Removal Reason                                       object
# Capital Asset Value For Amenity Trees               float64
# Carbon Storage In Kilograms                         float64
# Gross Carbon Sequestration Per Year In Kilograms    float64
# Pollution Removal Per Year In Grams                 float64
# dtype: object

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 2.3 Common and Scientific Names
# The file `"tree_common_names.json"` is a json file.  Use the appropriate function to load it into a Pandas DataFrame.

# %%
# Create a Pandas dataframe called trees that contains the contents of the json file
tree_json = pd.read_json ("tree_common_names.json")

# %%
# Display the first few rows
tree_json.head()
# Out:
#               Scientific Name          Common Name
# 0      Carpinus betulus Lucas  Hornbeam - European
# 1            Prunus 'Pandora'  Cherry - Ornamental
# 2  Tilia unidentified species                 Lime
# 3   Rosa unidentified species                 None
# 4               Cedrus libani     Cedar of Lebanon

# %%
# Get the number of rows and columns
tree_json.shape
# Out:
# (589, 2)

# %%
# Get a list of all the columns in the dataframe
tree_json.columns
# Out:
# Index(['Scientific Name', 'Common Name'], dtype='object')

# %%
# List the data types of each column
tree_json.dtypes
# Out:
# Scientific Name    object
# Common Name        object
# dtype: object

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 2.4 Review
# At the end of this task you should have a good basic understanding of the contents and overall shape of the different data files.  If you don't, do back and review the outputs above.

# %% [markdown]
# ## Task 3: Further Inspect the Datasets
# The initial inspection gave you a very high-level understanding of the data.  We will now drill a bit deeper and try to understand the data column-by-column.
#
# For columns with a string data type (`object` in Pandas) we have **qualitative** data.  It would be good to know how many *different* values we have in the column, what those values are and the *count* how many of each different value we have.  This will help us understand if the qualitative variable is **binary**, **nominal** or **ordinal**.
#
# For columns with a numeric data type (`int` or `float`) we have **quantitative** data.  Usually integer type variables can the thought of as **discrete** and float type variables can be thought of as **continuous**.  It would be good to know some summary descriptive statistics for these columns.
#
# If you are unsure of what these different data classifications mean, read this:
#
# [Types of Variables](https://openclassrooms.com/en/courses/6037301-perform-an-initial-data-analysis/6051886-discover-the-four-variable-types)
#
# You can get the list of values and counts for a column using this function:
#
# [pandas.Series.value_counts](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html)
#
# You can get the descriptive statistics for a DataFrame using this function:
#
# [pandas.DataFrame.describe](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)
#
# Note that Pandas may treat integer columns as floats if there are null values in the columns.  So if you see a float data type it might be worth checking the actual values to confirm if it really is a float or if it really is an int with nulls.  You can check the actual values with:
#
# [pandas.Series.unique](https://pandas.pydata.org/docs/reference/api/pandas.Series.unique.html)

# %% [markdown]
# ### 3.1 Further Inspect the Trees Dataset
# Let's start with the trees dataset.

# %% [markdown]
# #### 3.1.a Counts of Values for String Types Columns
# Go through each column that is a string (object) type and count the number of rows for each value in the column.  After each one, classify the data as binary, nominal or ordinal using a markdown comment.
#
# I've done the first one for you.

# %% [markdown]
# **Site Name**

# %%
# List of values in Site Name column and their counts
trees["Site Name"].value_counts()
# Out:
# WATERLOW PARK (LS)                         920
# Alexandra & Ainsworth Estate               289
# Belsize nature reserve, Russell Nursery    278
# Holly Lodge Estate                         272
# LINCOLN'S INN FIELDS, GARDENS (LS)         193
#                                           ...
# GOLDINGTON CRESCENT                          1
# ALLCROFT ROAD                                1
# WOBURN WALK, LAND BEHIND 4-18                1
# KILBURN PRIORY                               1
# GOODGE PLACE                                 1
# Name: Site Name, Length: 1135, dtype: int64

# %% [markdown]
# Site Name is **qualitative nominal**.

# %% [markdown]
# Now do the same on the other string columns.  Use `value_counts()` and then classify as binary, ordered or unordered using a markdown comment.  As you do each one, stop and look at the values and counts and think about how the data in the column might be useful for supporting the council's initiatives.  Don't just treat this as a mechanical copy/paste task. The objective is, after all, to get really intimate with the data!

# %%
trees["Contract Area"].value_counts()
# Out:
# Highways              10062
# Housing                7500
# Parks                  4330
# Education              1288
# Corporate Landlord      264
# Name: Contract Area, dtype: int64

# %% [markdown]
# This data is **qualitative ordinal**.

# %%
trees["Scientific Name"].value_counts()
# Out:
# Platanus x hispanica                                 3340
# Tilia europaea                                       1468
# Acer pseudoplatanus                                   941
# Betula pendula                                        765
# Fraxinus excelsior                                    754
#                                                      ...
# Vacant Tree Pit (planned: Populus tremula)              1
# Liriodendron fastigiata                                 1
# Sequoia sempervirens                                    1
# Sorbus x hybrida                                        1
# Vacant Tree Pit (planned: Acer rubrum 'Amstrong')       1
# Name: Scientific Name, Length: 543, dtype: int64

# %% [markdown]
# This data is **qualitative nominal**.

# %%
trees["Ward Name"].value_counts()
# Out:
# Highgate                          2799
# St Pancras and Somers Town        1832
# Gospel Oak                        1541
# Kilburn                           1540
# Kentish Town                      1463
# Haverstock                        1424
# Hampstead Town                    1340
# Holborn and Covent Garden         1293
# Fortune Green                     1284
# Cantelowes                        1231
# Frognal and Fitzjohns             1229
# Bloomsbury                        1008
# Regent's Park                      989
# Swiss Cottage                      978
# Camden Town with Primrose Hill     899
# West Hampstead                     853
# King's Cross                       824
# Belsize                            691
# Name: Ward Name, dtype: int64

# %% [markdown]
# This data is **qualitative nominal**.

# %%
trees["Ward Code"].value_counts()
# Out:
# E05000137    2799
# E05000143    1832
# E05000134    1541
# E05000140    1540
# E05000139    1463
# E05000136    1424
# E05000135    1340
# E05000138    1293
# E05000132    1284
# E05000131    1231
# E05000133    1229
# E05000129    1008
# E05000142     989
# E05000144     978
# E05000130     899
# E05000145     853
# E05000141     824
# E05000128     691
# Name: Ward Code, dtype: int64

# %%
trees["Location"].value_counts()
# Out:
# (51.556205, -0.173776)    3
# (51.553475, -0.152668)    3
# (51.548133, -0.144922)    2
# (51.544482, -0.144465)    2
# (51.55468, -0.164744)     2
#                          ..
# (51.525312, -0.128846)    1
# (51.540297, -0.181512)    1
# (51.556013, -0.211326)    1
# (51.55969, -0.182457)     1
# (51.552397, -0.173397)    1
# Name: Location, Length: 23262, dtype: int64

# %% [markdown]
# This data is **qualitative ordinal**.

# %% [markdown]
# <hr/>

# %% [markdown]
# #### 3.1.b Descriptive Stats for Numeric Type Columns
# Use the `describe()` function to get the descriptive stats for the numeric columns.
#
# For each column, classify the column as discrete or continuous (use the data type to guide you, but check any floats to confirm whether they are really floats or just ints with null values.  Use `pandas.Series.unique()` to check this).

# %%
# Get the descriptive stats for the numeric columns
trees.describe()
# Out:
#        Number Of Trees  Height In Metres  Spread In Metres  \
# count     23422.000000      23006.000000      23006.000000
# mean          1.100034         10.307029          5.997612
# std           1.288041          6.325293          4.132379
# min           0.000000          0.000000          0.000000
# 25%           1.000000          5.000000          3.000000
# 50%           1.000000          9.000000          5.000000
# 75%           1.000000         15.000000          8.000000
# max          67.000000        127.000000         88.000000
#
#        Diameter In Centimetres At Breast Height        Easting       Northing  \
# count                              23005.000000   23444.000000   23444.000000
# mean                                  32.595262  526762.518171  184085.188662
# std                                   26.149994   25835.857212    9121.059755
# min                                    0.000000       0.000000       0.000000
# 25%                                   12.000000  526583.750000  183665.000000
# 50%                                   27.000000  528456.500000  184690.000000
# 75%                                   46.000000  529369.000000  185481.000000
# max                                  228.000000  531514.000000  196188.000000
#
#           Longitude      Latitude
# count  23388.000000  23388.000000
# mean      -0.155145     51.545115
# std        0.025058      0.013067
# min       -0.261719     51.512858
# 25%       -0.175734     51.537472
# 50%       -0.148478     51.546669
# 75%       -0.135978     51.554032
# max       -0.105858     51.650843

# %%
# Remind ourselves of the data types
trees.dtypes
# Out:
# Identifier                                          object
# Number Of Trees                                    float64
# Site Name                                           object
# Contract Area                                       object
# Scientific Name                                     object
# Inspection Date                             datetime64[ns]
# Inspection Due Date                                 object
# Height In Metres                                   float64
# Spread In Metres                                   float64
# Diameter In Centimetres At Breast Height           float64
# Ward Code                                           object
# Ward Name                                           object
# Easting                                              int64
# Northing                                             int64
# Longitude                                          float64
# Latitude                                           float64
# Location                                            object
# dtype: object

# %%
trees["Number Of Trees"].unique()
# Out:
# array([ 1.,  2.,  3.,  0., nan,  5.,  6.,  7., 18.,  8., 65.,  4., 10.,
#         9., 11., 50., 12., 15., 52., 40., 33., 13., 20., 67., 21., 32.,
#        24., 26., 16., 25., 51.])

# %%
trees["Height In Metres"].unique()
# Out:
# array([  nan,   5. ,   4. ,  14. ,   9. ,   0. ,   2. ,   2.5,   8. ,
#         13. ,  17. ,  10. ,   3. ,  19. ,   7. ,   6. ,   1.8,  15. ,
#         12. ,   1.5,  16. ,  20. ,  21. ,  24. ,  25. ,   2.7,  18. ,
#         11. ,  26. ,  22. ,   0.5,  16.1,  27. ,  28. ,   2.3,  22.3,
#         38. ,  15.5,  29. ,  23. ,  34. ,   3.5,   2.6,   1. ,   5.5,
#         22.5,   2.2,  36. ,  31. ,  96. ,  13.6, 127. ,  14.7,   4.5,
#         30. ,  35. ,  32. ,   9.4,  11.8,  33. ,  40. ,   2.1,   6.5,
#         41. ,  23.1,  37. ,  39. ,  12.5,   7.5,  13.7,  31.6,  23.8,
#          0.2,  12.3,  15.7,   6.8,   9.3,   3.8,  24.9,  17.4,   2.8,
#          3.2,  13.9,  12.4,  10.2,  10.8,  24.5,  30.4,   9.8,  11.4,
#         23.4,   3.7,  11.6,   7.7,   8.3,   3.6,  17.5,  19.5])

# %%
trees["Spread In Metres"].unique()
# Out:
# array([  nan,  4.  ,  1.  ,  6.  ,  7.  ,  0.  ,  1.5 ,  5.  ,  9.  ,
#        10.  ,  3.  ,  2.  , 13.  ,  2.5 , 12.  , 15.  , 14.  ,  8.  ,
#        11.  ,  0.6 ,  1.8 , 17.  , 20.  , 18.  , 16.  , 22.  , 19.  ,
#         5.5 , 26.  ,  1.4 , 23.  , 21.  , 28.  ,  1.2 ,  0.5 ,  3.5 ,
#        24.  ,  1.3 ,  1.6 , 30.  ,  1.7 , 27.  ,  4.2 , 11.02,  0.7 ,
#         6.5 ,  4.5 , 31.  , 25.  ,  0.8 ,  0.3 ,  2.2 ,  2.8 ,  1.65,
#        29.  , 88.  ])

# %%
trees["Diameter In Centimetres At Breast Height"].unique()
# Out:
# array([  nan,  10. ,   6. ,  26. ,  29. ,   5. ,   0. ,   4. ,  12. ,
#         59. ,  52. ,  23. ,  50. ,  63. ,  15. ,   3. ,  49. ,  42. ,
#         14. ,  19. ,   9. ,  70. ,  32. ,  28. ,  34. ,  20. ,  17. ,
#         27. ,  37. ,   8. ,  45. ,  18. , 119. ,   7. ,  38. ,  55. ,
#         41. ,  75. ,  31. ,  25. ,  11. ,  30. ,  43. ,  68. ,  92. ,
#         16. ,  35. ,  58. ,  72. ,  64. ,  13. ,  61. ,  69. ,  33. ,
#         47. ,  67. , 109. , 106. ,  24. ,  51. ,  40. ,  22. ,  60. ,
#         39. ,  46. ,  57. ,  21. ,  54. , 117. ,  44. ,  82. , 114. ,
#         65. ,  84. , 118. ,   1. ,  89. ,  53. ,  36. ,  93. ,  88. ,
#         86. , 163. ,  66. ,  81. ,  74. , 100. ,  48. ,  73. ,  95. ,
#        129. ,  62. ,  85. ,  56. ,   3.5, 161. ,  71. , 105. , 102. ,
#         80. ,  87. , 101. ,  76. , 113. , 108. , 160. , 132. ,  90. ,
#        145. , 130. ,  79. , 228. , 110. ,  83. ,  78. , 122. , 170. ,
#        115. ,   2. ,  77. , 107. ,  96. , 126. ,  91. , 104. , 158. ,
#         99. ,  94. ,  16.5, 127. , 151. , 103. , 112. ,  98. ,  97. ,
#        136. , 125. , 111. , 124. , 139. , 156. , 120. , 148. , 144. ,
#        140. , 121. , 143. ,  17.5, 154. , 159. , 142. , 197. , 123. ,
#        149. , 155. , 191. , 131. , 147. , 162. , 116. , 152. , 153. ,
#        165. , 137. , 200. , 177. , 133. , 128. , 134. ,  11.5, 135. ,
#        150. , 187. , 210. , 166. , 138. ,  10.5, 206. , 141. , 209. ,
#        184. , 173. , 192. ,   7.5, 194. , 157. , 146. , 185. ])

# %% [markdown]
# <hr/>

# %% [markdown]
# All this data is **quantitative continuous**.

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 3.2 Further Inspect the Environmental Dataset
# Now repeat the above for the environmental dataset.
#
# #### 3.2.a Counts of Values for String Type Columns
# For each string column in the environmental dataset show the counts of the unique values.

# %%
trees_cvs_file.dtypes
# Out:
# Identifier                                           object
# Maturity                                             object
# Physiological Condition                              object
# Tree Set To Be Removed                               object
# Removal Reason                                       object
# Capital Asset Value For Amenity Trees               float64
# Carbon Storage In Kilograms                         float64
# Gross Carbon Sequestration Per Year In Kilograms    float64
# Pollution Removal Per Year In Grams                 float64
# dtype: object

# %%
trees_cvs_file.describe()
# Out:
#        Capital Asset Value For Amenity Trees  Carbon Storage In Kilograms  \
# count                           22982.000000                 20555.000000
# mean                            14056.393047                   467.465454
# std                             24803.806595                   844.926555
# min                                 0.000000                     0.500000
# 25%                              1035.650000                    24.800000
# 50%                              5443.660000                   163.900000
# 75%                             16781.420000                   497.300000
# max                            504725.720000                  6000.000000
#
#        Gross Carbon Sequestration Per Year In Kilograms  \
# count                                      20555.000000
# mean                                           8.675057
# std                                            8.681446
# min                                            0.000000
# 25%                                            2.200000
# 50%                                            6.100000
# 75%                                           11.700000
# max                                           53.800000
#
#        Pollution Removal Per Year In Grams
# count                         20555.000000
# mean                            217.740316
# std                             306.751920
# min                               0.300000
# 25%                              29.300000
# 50%                             108.100000
# 75%                             297.600000
# max                            8223.700000

# %%
trees_cvs_file["Capital Asset Value For Amenity Trees"].unique()
# Out:
# array([1.1507000e+02, 7.5180800e+03, 2.0419630e+04, ..., 3.3664130e+04,
#        3.6269450e+04, 1.4801215e+05])

# %%
trees_cvs_file["Carbon Storage In Kilograms"].unique()
# Out:
# array([1.6000e+00,        nan, 4.2640e+02, ..., 4.7233e+03, 3.7305e+03,
#        4.8100e+02])

# %%
trees_cvs_file["Gross Carbon Sequestration Per Year In Kilograms"].unique()
# Out:
# array([ 0.5,  nan,  8.8,  9.6,  1.4, 10.1,  0.8,  7.9, 24.2,  2.4,  0.9,
#         3. , 14.6,  8.1,  4.1,  1.8, 18.8, 24.4, 13.4,  4.3,  6.5,  1.3,
#         0.6,  2.5, 13.1,  2.1,  3.9, 15.9,  1. ,  6.6,  0.4,  3.4,  2.9,
#        28.7,  0.7,  1.5, 12.5, 25.4, 11.2,  9. , 23.9,  4.4, 11.5, 11. ,
#         8.4, 10.9, 10.7,  6.9,  7. ,  3.8,  3.2,  6.1,  8.6, 30.2,  3.7,
#        15. , 30.4,  7.6, 20.1, 10.2,  8.3, 39.9,  0.3,  4.9, 14.3, 13.5,
#        16.7,  8.9,  1.6,  4.2,  3.6,  4. ,  6.7,  0.1, 19.7, 24.6,  6.4,
#         5.4,  5.9, 12.2,  7.3, 13. ,  7.1, 36.9,  9.3, 18.2, 10. ,  4.7,
#         5. , 29.8, 17.8, 18.5, 17.6,  7.2,  4.8,  5.6,  5.3, 10.5, 12.9,
#         9.4,  7.8,  1.1, 19.2, 37.3,  2.7, 12.8, 17. , 15.5, 27.6, 34.2,
#         5.7,  5.8, 17.3, 20.4,  9.9, 15.6,  7.4, 11.8,  9.2,  2.6, 21.7,
#        11.3, 10.8, 29.4, 23.1, 26.5,  1.2, 10.6, 33.6, 23.6, 11.7, 17.4,
#        15.1, 16.6,  2.3, 13.3, 16.3, 18.3, 10.4, 19. ,  1.7,  3.3, 14.1,
#         5.5, 12.6, 14.5,  3.5,  8.7, 36.6, 17.7,  5.1, 21.1, 20.2,  7.7,
#        15.2,  7.5, 30.5, 13.8,  4.6, 39.2, 37.8, 13.2, 51. , 11.6,  6.8,
#        21. ,  5.2,  8. ,  4.5, 15.3, 13.7, 18. ,  6.3,  2. ,  2.8,  9.1,
#         6. , 12.4, 11.4, 18.6,  1.9, 23.5, 18.9, 26.2, 12.1, 41.7,  2.2,
#        14.7, 14.4,  9.7, 23. , 22.1, 15.7, 12. , 14.8, 19.9, 29.7, 11.1,
#        19.6, 12.7, 31.9, 33.2, 19.1,  6.2, 28.4, 27. , 17.5, 16.4, 27.7,
#        38.4, 43.9, 35.4,  8.2, 37.1, 29.5, 22.2, 17.1, 26.3, 21.2, 20.5,
#        11.9, 31.3, 14.2,  8.5, 26.8,  0.2, 16.8, 35.6, 20.8, 22.3, 19.4,
#        20. , 14. , 36.1, 20.9, 15.8, 14.9,  9.5, 28.3, 16.9,  3.1, 37.6,
#        34.7, 17.9, 35.3,  9.8, 16.5, 21.4, 19.3, 28.5, 29. , 33.5, 40.7,
#        28.6, 13.6, 27.1, 26.7, 13.9, 21.3, 23.8, 35.1, 40.5, 32.9, 18.1,
#        37. , 20.6, 35.2, 12.3, 41.8, 22.7, 21.5, 35.7, 32.4, 16.1, 31.1,
#        25.3, 26. , 23.4, 30.1, 42.1, 36.5, 10.3, 44.3, 16. , 23.2, 28.8,
#        21.9, 32. , 30.3, 15.4, 24.3, 26.9, 25.8, 28.2, 22.8, 42.3, 33.9,
#        25.6, 38.6, 18.4, 31.2, 32.7, 28. , 30.6, 42. , 27.3, 33.8, 21.6,
#        33.3, 35.9, 24. , 40.6, 42.7, 31.5, 22.5, 20.7, 33.1, 35.5, 27.5,
#        24.8, 26.4, 22.6, 18.7, 32.6, 36.4, 16.2, 38.5, 22.4, 22.9, 29.2,
#        25.9, 19.5, 24.5, 20.3, 27.9, 29.6, 25. , 27.4, 30.7, 25.1, 34.6,
#        38. , 34.4, 36.7, 34.1, 32.5, 27.8, 32.8, 43.1, 17.2, 37.5, 39.3,
#        29.1, 30.8, 34.8, 29.9, 38.3, 23.3, 21.8, 41.3, 38.7, 36.3, 30. ,
#        41.5, 37.2, 24.9, 19.8, 28.9, 42.2, 39.5, 31.8, 37.4, 24.1,  0. ,
#        37.7, 32.3, 36.8, 27.2, 24.7, 36.2, 39.7, 42.9, 49.5, 31.6, 38.9,
#        40.9, 44.2, 32.1, 42.5, 25.7, 35.8, 38.2, 40.8, 35. , 34. , 31.7,
#        40.1, 26.1, 25.2, 39. , 41.1, 33.4, 32.2, 43.3, 33.7, 26.6, 39.1,
#        41.4, 43.2, 31. , 41.9, 41. , 42.4, 43. , 40.3, 40.2, 29.3, 31.4,
#        22. , 42.8, 43.7, 23.7, 34.5, 41.6, 39.6, 39.8, 37.9, 43.8, 42.6,
#        41.2, 43.6, 36. , 39.4, 43.5, 25.5, 38.1, 34.9, 28.1, 43.4, 53.8,
#        30.9, 40.4, 34.3, 45.5, 52.7, 40. , 38.8, 44.9, 33. ])

# %%
trees_cvs_file["Pollution Removal Per Year In Grams"].unique()
# Out:
# array([  5.7,   nan, 215.2, ...,   8. , 399.9,  60.1])

# %% [markdown]
# All this data is **qualitative discrete**.

# %% [markdown]
# <hr/>

# %% [markdown]
# #### 3.2.b Descriptive Stats for Numeric Type Columns
# For each numeric column in the environmental dataset show the descriptive stats

# %%
# Get the descriptive stats for all numeric columns
# TODO
trees_cvs_file.describe()
# Out:
#        Capital Asset Value For Amenity Trees  Carbon Storage In Kilograms  \
# count                           22982.000000                 20555.000000
# mean                            14056.393047                   467.465454
# std                             24803.806595                   844.926555
# min                                 0.000000                     0.500000
# 25%                              1035.650000                    24.800000
# 50%                              5443.660000                   163.900000
# 75%                             16781.420000                   497.300000
# max                            504725.720000                  6000.000000
#
#        Gross Carbon Sequestration Per Year In Kilograms  \
# count                                      20555.000000
# mean                                           8.675057
# std                                            8.681446
# min                                            0.000000
# 25%                                            2.200000
# 50%                                            6.100000
# 75%                                           11.700000
# max                                           53.800000
#
#        Pollution Removal Per Year In Grams
# count                         20555.000000
# mean                            217.740316
# std                             306.751920
# min                               0.300000
# 25%                              29.300000
# 50%                             108.100000
# 75%                             297.600000
# max                            8223.700000

# %%
# Remind ourselves of the data types
# TODO
trees_cvs_file.dtypes
# Out:
# Identifier                                           object
# Maturity                                             object
# Physiological Condition                              object
# Tree Set To Be Removed                               object
# Removal Reason                                       object
# Capital Asset Value For Amenity Trees               float64
# Carbon Storage In Kilograms                         float64
# Gross Carbon Sequestration Per Year In Kilograms    float64
# Pollution Removal Per Year In Grams                 float64
# dtype: object

# %% [markdown]
# <hr/>
#
# Find out if floats are really floats or ints with nulls.

# %%
trees_cvs_file["Capital Asset Value For Amenity Trees"].unique()
# Out:
# array([1.1507000e+02, 7.5180800e+03, 2.0419630e+04, ..., 3.3664130e+04,
#        3.6269450e+04, 1.4801215e+05])

# %%
trees_cvs_file["Carbon Storage In Kilograms"].unique()
# Out:
# array([1.6000e+00,        nan, 4.2640e+02, ..., 4.7233e+03, 3.7305e+03,
#        4.8100e+02])

# %%
trees_cvs_file["Gross Carbon Sequestration Per Year In Kilograms"].unique()
# Out:
# array([ 0.5,  nan,  8.8,  9.6,  1.4, 10.1,  0.8,  7.9, 24.2,  2.4,  0.9,
#         3. , 14.6,  8.1,  4.1,  1.8, 18.8, 24.4, 13.4,  4.3,  6.5,  1.3,
#         0.6,  2.5, 13.1,  2.1,  3.9, 15.9,  1. ,  6.6,  0.4,  3.4,  2.9,
#        28.7,  0.7,  1.5, 12.5, 25.4, 11.2,  9. , 23.9,  4.4, 11.5, 11. ,
#         8.4, 10.9, 10.7,  6.9,  7. ,  3.8,  3.2,  6.1,  8.6, 30.2,  3.7,
#        15. , 30.4,  7.6, 20.1, 10.2,  8.3, 39.9,  0.3,  4.9, 14.3, 13.5,
#        16.7,  8.9,  1.6,  4.2,  3.6,  4. ,  6.7,  0.1, 19.7, 24.6,  6.4,
#         5.4,  5.9, 12.2,  7.3, 13. ,  7.1, 36.9,  9.3, 18.2, 10. ,  4.7,
#         5. , 29.8, 17.8, 18.5, 17.6,  7.2,  4.8,  5.6,  5.3, 10.5, 12.9,
#         9.4,  7.8,  1.1, 19.2, 37.3,  2.7, 12.8, 17. , 15.5, 27.6, 34.2,
#         5.7,  5.8, 17.3, 20.4,  9.9, 15.6,  7.4, 11.8,  9.2,  2.6, 21.7,
#        11.3, 10.8, 29.4, 23.1, 26.5,  1.2, 10.6, 33.6, 23.6, 11.7, 17.4,
#        15.1, 16.6,  2.3, 13.3, 16.3, 18.3, 10.4, 19. ,  1.7,  3.3, 14.1,
#         5.5, 12.6, 14.5,  3.5,  8.7, 36.6, 17.7,  5.1, 21.1, 20.2,  7.7,
#        15.2,  7.5, 30.5, 13.8,  4.6, 39.2, 37.8, 13.2, 51. , 11.6,  6.8,
#        21. ,  5.2,  8. ,  4.5, 15.3, 13.7, 18. ,  6.3,  2. ,  2.8,  9.1,
#         6. , 12.4, 11.4, 18.6,  1.9, 23.5, 18.9, 26.2, 12.1, 41.7,  2.2,
#        14.7, 14.4,  9.7, 23. , 22.1, 15.7, 12. , 14.8, 19.9, 29.7, 11.1,
#        19.6, 12.7, 31.9, 33.2, 19.1,  6.2, 28.4, 27. , 17.5, 16.4, 27.7,
#        38.4, 43.9, 35.4,  8.2, 37.1, 29.5, 22.2, 17.1, 26.3, 21.2, 20.5,
#        11.9, 31.3, 14.2,  8.5, 26.8,  0.2, 16.8, 35.6, 20.8, 22.3, 19.4,
#        20. , 14. , 36.1, 20.9, 15.8, 14.9,  9.5, 28.3, 16.9,  3.1, 37.6,
#        34.7, 17.9, 35.3,  9.8, 16.5, 21.4, 19.3, 28.5, 29. , 33.5, 40.7,
#        28.6, 13.6, 27.1, 26.7, 13.9, 21.3, 23.8, 35.1, 40.5, 32.9, 18.1,
#        37. , 20.6, 35.2, 12.3, 41.8, 22.7, 21.5, 35.7, 32.4, 16.1, 31.1,
#        25.3, 26. , 23.4, 30.1, 42.1, 36.5, 10.3, 44.3, 16. , 23.2, 28.8,
#        21.9, 32. , 30.3, 15.4, 24.3, 26.9, 25.8, 28.2, 22.8, 42.3, 33.9,
#        25.6, 38.6, 18.4, 31.2, 32.7, 28. , 30.6, 42. , 27.3, 33.8, 21.6,
#        33.3, 35.9, 24. , 40.6, 42.7, 31.5, 22.5, 20.7, 33.1, 35.5, 27.5,
#        24.8, 26.4, 22.6, 18.7, 32.6, 36.4, 16.2, 38.5, 22.4, 22.9, 29.2,
#        25.9, 19.5, 24.5, 20.3, 27.9, 29.6, 25. , 27.4, 30.7, 25.1, 34.6,
#        38. , 34.4, 36.7, 34.1, 32.5, 27.8, 32.8, 43.1, 17.2, 37.5, 39.3,
#        29.1, 30.8, 34.8, 29.9, 38.3, 23.3, 21.8, 41.3, 38.7, 36.3, 30. ,
#        41.5, 37.2, 24.9, 19.8, 28.9, 42.2, 39.5, 31.8, 37.4, 24.1,  0. ,
#        37.7, 32.3, 36.8, 27.2, 24.7, 36.2, 39.7, 42.9, 49.5, 31.6, 38.9,
#        40.9, 44.2, 32.1, 42.5, 25.7, 35.8, 38.2, 40.8, 35. , 34. , 31.7,
#        40.1, 26.1, 25.2, 39. , 41.1, 33.4, 32.2, 43.3, 33.7, 26.6, 39.1,
#        41.4, 43.2, 31. , 41.9, 41. , 42.4, 43. , 40.3, 40.2, 29.3, 31.4,
#        22. , 42.8, 43.7, 23.7, 34.5, 41.6, 39.6, 39.8, 37.9, 43.8, 42.6,
#        41.2, 43.6, 36. , 39.4, 43.5, 25.5, 38.1, 34.9, 28.1, 43.4, 53.8,
#        30.9, 40.4, 34.3, 45.5, 52.7, 40. , 38.8, 44.9, 33. ])

# %%
trees_cvs_file["Pollution Removal Per Year In Grams"].unique()
# Out:
# array([  5.7,   nan, 215.2, ...,   8. , 399.9,  60.1])

# %% [markdown]
# <hr/>

# %% [markdown]
# All this data is **qualitative continuous**.

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 3.3 Further Inspect the Common Names Dataset
# Now repeat the above for the common names dataset.
#
# #### 3.3.a (Names) Counts of Values for String Type Columns
# For each string column in the common names dataset show the counts of the unique values.

# %%
tree_json.describe()
# Out:
#                   Scientific Name Common Name
# count                         589         565
# unique                        560         431
# top     Cupressocyparis leylandii      Cherry
# freq                            2          12

# %%
tree_json["Scientific Name"].unique()
# Out:
# array(['Carpinus betulus Lucas', "Prunus 'Pandora'",
#        'Tilia unidentified species', 'Rosa unidentified species',
#        'Cedrus libani', "Acer x 'freemanii'", 'Crataegus monogyna',
#        'Vacant Tree Pit (planned: Sorbus Autumn Spire)',
#        "Sorbus aria 'Magnifica'", 'Liriodendron tulipifera',
#        'Euodia hupehensis', 'Sorbus torminalis', 'Tilia americana',
#        'Araucaria araucana', 'Morus nigra', 'Parrotia persica vanessa',
#        'Vacant Tree Pit (planned: Hamamelis intermedia Jelena)',
#        'Quercus robur', 'Sorbus domestica',
#        'Vacant Tree Pit (planned: Hippophae salicifolia ‘Streetw)',
#        'Pinus sylvestris', 'Tamarix tetrandra',
#        "Crataegus monogyna 'Stricta'", 'Clerodendrum trichotomum',
#        'Cercis siliquastrum', 'Ligustrum lucidum',
#        "Betula pendula 'Youngii'", "Fraxinus excelsior 'Pendula'",
#        "Vacant Tree Pit (planned: Acer campestre 'Elsrijk')",
#        "Malus 'Rudolph'", "Corylus avellana 'Contorta'",
#        'Vacant Tree Pit (planned: Acer campestre Elegant)',
#        'Prunus dulcis', 'Salix sepulcralis Erythroflexu',
#        "Ilex aquifolium 'unidentified", 'Liquidambar sty Lane Roberts',
#        'Populus nigra', 'Corylus avellana', 'Griselinia littoralis',
#        'Taxus Unknown', 'Alnus rubra', 'Betula pendula',
#        'Buddleia Species', 'Cedrus atlantica',
#        'Vacant Tree Pit (planned: Cladrastis kentukea)',
#        'Cordyline australis (palm)',
#        'Vacant Tree Pit (planned: carpinus betulus Lucas)',
#        'Cornus Stella Pink', 'Vacant Tree Pit (planned: Malus trilobata)',
#        "Prunus serrulata 'Autumn Glory",
#        'Vacant Tree Pit (planned: Fagus sylvatica)', 'Unknown',
#        'Betula jacquemontii', 'Betula maximowicziana',
#        'Metasequoia glyptostroboides', 'Lagerstroemia indica Rosa Nova',
#        'Ginkgo biloba globosa', 'Crataegus unidentified species',
#        'Paulownia Tomentosa',
#        'Vacant Tree Pit (planned: Koelreuteria paniculata)',
#        'Vacant Tree Pit (planned: Picea abies)', 'Sorbus',
#        "Malus 'Profusion'", 'Salix unidentified species',
#        'Malus trilobata', "Acer platanoides 'Purpureum'",
#        'Vacant Tree Pit (planned: Malus domestica cultivar)',
#        'Tilia platyphyllos', 'Viburnum tinus',
#        'Eucalyptus unkown species', 'Platanus orientalis', 'Stump Only',
#        'TFL Tree', 'Hedera (Species) - Ivy',
#        "Fraxinus angustifolia 'pendula", "Sorbus aria 'Majestica'",
#        "Acer platanoides 'Schwedleri'", 'Acer saccharum',
#        "Salix matsudana 'Tortuosa'", 'Sorbus vilmorinii',
#        'Castanea sativa', 'Pterocarya Fraxinifolia',
#        'Vacant Tree Pit (planned: Sorbus X thuringiaca)',
#        "Sorbus aucuparia 'Fastigiata'", 'Pyrus unidentified species',
#        "Vacant Tree Pit (planned: Sorbus 'Glowing Pink')",
#        'Zelkova serrata Green Vase', 'Lophozonia obliqua',
#        'Zelkova serrata', "Amelanchier lamarckii 'Robin H",
#        'Prunus laurocerasus', 'Juniperus unidentified species',
#        "Fraxinus oxycarpa 'Raywood'", "Sorbus aucuparia 'Sheerwater",
#        'Olea europaea',
#        "Vacant Tree Pit (planned: Pyrus calleryana 'Chanticclere)",
#        'Acer platanoides', 'Prunus "sunset boulevard"',
#        'Catalpa speciosa', "Prunus 'Tai Haku'",
#        'Vacant Tree Pit (planned: Nothofagus antarctica)', 'Ulmus glabra',
#        "Acer pseudoplatanus 'Purpureum", "Acer pseudoplatanus 'Unidentif",
#        'Acer platanoides "Prin. Gold"', 'Populus alba', 'Prunus spinosa',
#        'Robinia pseudoacacia', "Prunus subhirtella 'Autumnalis",
#        "Acer rubrum 'Armstrong'", 'Rhus typhina',
#        'Vacant Tree Pit (planned: Betula ermanii)',
#        "Sorbus 'Glowing Pink'", 'Prunus x schmittii', 'Tilia mongolica',
#        'Vacant Tree Pit (planned: Zelkova serrata Green Vase)',
#        'Juniperus communis', "Sorbus intermedia 'Brouwers'",
#        'Celtis australis', 'Malus hupehensis',
#        "Acer saccharinum 'Lutescens'", 'Gymnocladus dioicus',
#        'Acer campestre Lienco', "Sorbus 'Joseph Rock'",
#        "Robinia pseudoacacia 'Frisia'", "Acer pseudoplatanus 'Worleei'",
#        'Acer unidentified Species', "Prunus virginiana 'Canada Red'",
#        'Malus x purpurea', 'Prunus unidentified hybrid',
#        'Vacant Tree Pit (planned: Betula pendula)',
#        'Publications/Periodicals GD230', 'Malus toringo Scarlet Brouwers',
#        'Fraxinus americana', "Crataegus oxyacantha 'Pauls Sc",
#        'Juniperus foetidissima', "Quercus hispanica 'Lucombeana'",
#        "Malus x robusta 'Red Sentinel'", 'Euonymus europaeus',
#        'Crataegus x lavallei', 'Salix alba',
#        'Sorbus aucuparia Cardinal Roya', "Sorbus thibetica 'John Mitchel",
#        "Cotoneaster cornubia'", 'Ulmus New Horizon',
#        'Vacant Tree Pit (planned: Cupressus arizonica Glauca)',
#        "Acer pseudoplatanus 'Atropurpu",
#        'Vacant Tree Pit (planned: Platanus X hispanica)',
#        "Prunus sargentii 'Rancho'", "Acer platanoides 'Globosum'",
#        "Vacant Tree Pit (planned: Acer rubrum 'Amstrong')",
#        'Prunus domestica',
#        "Vacant Tree Pit (planned: Photinia x fraseri 'Red Robin')",
#        'Pinus nigra', 'Vacant Tree Pit (planned: Pyrus communis)',
#        'Sorbus hupehensis', "Acer pseudoplatanus 'Variegatu",
#        "Acer saccharinum 'Laciniatum'", 'Magnolia kobus',
#        'Vacant Tree Pit (planned: Ginkgo biloba)', 'Crataegus oxyacantha',
#        'Sorbus aria', "Prunus cerasifera 'Pissardii'",
#        "Vacant Tree Pit (planned: Cornus Eddie's White Wonder)",
#        'Vacant Tree Pit (planned: Access)', 'Betula utilis Jermyns',
#        "Castanea sativa 'Albomarginata", 'Tilia americana American sentr',
#        'Ulmus dodoens', 'Tilia henryana',
#        'Betula  jacquemontii Doorenbos', 'Celtis occidentalis',
#        'Vacant Tree Pit (planned: Carya illionensis)', 'Tilia euchlora',
#        'Chitalpa x tashkentensis Summe', "Betula pendula 'Dalecarlica'",
#        "Acer platanoides 'Erectum'", "Acer campestre 'Nanum'",
#        'Taxus baccata', 'Lagerstroemia indica Muskogee',
#        'Vacant Tree Pit (planned: Celtis australis)',
#        'Vacant Tree Pit (planned: Acer campestre eco sentry)',
#        'Acer davidii', 'Vacant Tree Pit (planned: Gymnocladus dioicus)',
#        'Platanus x hispanica Tremonia', "Chamaecyparis lawsoniana 'unid",
#        "Pyrus salicifolia 'Pendula'", 'Cornus mas',
#        "Vacant Tree Pit (planned: Malus 'Mokum')",
#        "Taxus baccata 'Fastigiata'", 'Magnolia wilsonii',
#        "Fraxinus excelsior 'Jaspidea'", 'Quercus palustris',
#        "Quercus robur 'Fastigiata'", 'Trachycarpus fortunei',
#        'Rhododendron ponticum', "Acer platanoides 'Goldsworth P",
#        'Tilia cordata', 'Alnus viridis', 'Malus domestica cultivar',
#        "Sorbus 'Sunshine'", "Acer platanoides 'Crimson King",
#        "Acer platanoides 'Columare'", 'Betula pendula purpurea',
#        'Pittosporum  tenuifolium', 'Acer ginnala',
#        'Liquidambar styraciflua', 'Magnolia grandiflora',
#        'Carya illinoinensis', "Robinia pseudoacacia 'Inermis'",
#        'Cupressus arizonica Glauca', 'Buddleia davidii',
#        'Magnolia stellata', 'Populus tremula', 'Betula papyrifera',
#        'Salix alba chermesina', 'Magnolia x soulangeana',
#        'Mespilus germanica', "Malus 'Mokum'", "Acer campestre 'Elsrijk'",
#        'Salix babylonica', "Vacant Tree Pit (planned: Prunus 'Accolade')",
#        'Malus transitoria', "Alnus glutinosa 'imperialis'",
#        'Prunus kanzan', 'Amelanchier laevis',
#        'Vacant Tree Pit (planned: Cercis siliquastrum)',
#        "Sorbus 'Golden Wonder'", 'Salix x chrysocoma',
#        'Vacant Tree Pit (planned: Robinia pseudoacacia)',
#        'Betula utilis Edinburgh', "Malus 'Golden hornet'",
#        'Ilex unidentified species', 'Cotoneaster unidentified speci',
#        'Fraxinus excelsior',
#        'Vacant Tree Pit (planned: Cornus kousa Milky Way)', 'Morus alba',
#        "Malus 'Red Profusion'",
#        'Vacant Tree Pit (planned: Sophora japonica)',
#        'Prunus subhirtella', 'Alnus glutinosa Laciniata',
#        "Prunus 'Shirotae'", 'Ginkgo biloba',
#        'Vacant Tree Pit (planned: Tilia tomentosa)',
#        'Prunus domestica Victoria', 'Malus unidentified species',
#        'Pseudotsuga menziesii', 'Acer platanoides Deborah',
#        'Prunus Serrulata', "Tilia cordata 'Green spire'",
#        'Catalpa bignonioides Aurea', 'Ulmus x hollandica',
#        'Pinus wallichiana', "Fraxinus ornus 'Meczek'",
#        'Vacant Tree Pit (planned: Ulmus New Horizon)',
#        "Prunus 'Pink Shell'", "Carpinus betulus 'Fasticiata'",
#        'Zelkova carpinifolia', 'Abies alba', 'Aesculus hippocastanum',
#        "Acer negundo 'Flamingo'", 'Aesculus x carnea', 'Acer negundo',
#        "Fagus sylvatica 'Dawyck'", "Fagus sylvatica 'Purpurea'",
#        'Crataegus crus-galli', "Sorbus aucuparia 'Beissneri'",
#        'Cedrus deodara', "Betula pendula 'Zwisters Glory",
#        'Chamaecyparis lawsoniana', 'Aesculus hippocastanum Baumann',
#        'Betula unidentified species', 'Amelanchier lamarckii',
#        'Sequoia sempervirens', "Acer platanoides 'Unknown vari",
#        "Salix caprea 'Pendula'", 'Crataegus prunifolia',
#        "Ulmus glabra 'Camperdownii'", 'Fortunella japonica',
#        'Prunus x yedoensis',
#        'Vacant Tree Pit (planned: Liquidambar styraciflua)',
#        'Sorbus commixta', 'Parrotia persica', "Malus 'John Downie'",
#        'Pyrus calleryana Chant. Red.Sp',
#        'Vacant Tree Pit (planned: Magnolia x soulangeana)',
#        'Thuja plicata', "Sorbus aucuparia 'Asplenifolia",
#        'Taxodium distichum', "Magnolia 'Galaxy'", "Salix alba 'Tristis'",
#        'Syringa vulgaris', 'Liriodendron fastigiata',
#        'Vacant Tree Pit (planned: Corylus colurna)',
#        'Cupressus unidentified species', 'Ligustrum vulgare',
#        'Picea unidentified species', 'Sorbus x hybrida',
#        "Magnolia × loebneri 'Merrill'",
#        'Vacant Tree Pit (planned: Castanea sativa)', 'Eucommia ulmoides',
#        'Vacant Tree Pit (planned: Eucommia ulmoides)',
#        'Eucalyptus niphophila', 'Hibiscus resi',
#        'Amelanchier alnifolia obelisk',
#        'Vacant Tree Pit (planned: Pinus sylvestris)',
#        'Vacant Tree Pit (planned: Sorbus aria)', 'Acacia dealbata',
#        'Quercus petraea', "Malus 'Everest'",
#        'Vacant Tree Pit (planned: Acer rubrum October Glory)',
#        "Prunus x hillieri 'Spire'", 'Salix fragilis',
#        "Photinia x fraseri 'Red Robin'", "Sorbus thibetica 'Mitchellii'",
#        'Catalpa bignonioides', 'Alnus cordata',
#        'Vacant Tree Pit (planned: Catalpa bignonioides)',
#        'Sambucus nigra', 'Acer saccharinum', 'Platanus x hispanica',
#        'Ficus carica', "Carpinus betulus 'Columnaris'",
#        'Laburnum anagyroides', 'Acer rubrum red sunset', 'Fraxinus ornus',
#        'Betula nigra',
#        "Vacant Tree Pit (planned: Acer campestre 'Nanum')",
#        'Vacant Tree Pit (planned: Metasequoia glyptostroboides)',
#        "Acer platanoides 'Emerald Que'", 'Prunus avium',
#        'Vacant Tree Pit (planned: Prunus sargentii)', 'Acer griseum',
#        'Arbutus unedo', 'Fremontodendron californicum',
#        "Aesculus x carnea 'Briotii'",
#        'Vacant Tree Pit (planned: Populus alba)',
#        "Acer platanoides 'Drummondii'", 'Salix caprea',
#        'Vacant Tree Pit (planned: Carpinus bet. Fast. Frans F.)',
#        'Ceanothus unknown species', 'Sorbus sargentiana',
#        'Cornus florida', 'Quercus castaneifolia', 'Juglans nigra',
#        'Abies noblis',
#        'Vacant Tree Pit (planned: Parrotia persica vanessa)',
#        'Acer campestre', 'Corylus colurna', 'Aesculus flava',
#        'Broussonetia papyrifera', 'Sorbus intermedia',
#        'Malus yunnanensis veitchii', "Fraxinus excelsior 'Diversifol",
#        "Prunus 'Accolade'", "Prunus cerasifera 'Nigra'",
#        "Vacant Tree Pit (planned: Acer campestre 'Streetwise')",
#        'Quercus rubra', 'Crataegus x prunifolia',
#        "Sorbus x thuringiaca 'Fastigia", 'Fraxinus unidentified species',
#        'Carpinus betulus', "x Cupresocyparis leylandii 'Ca",
#        'Ilex aquifolium', 'Carpinus bet. Fast. Frans F.', 'Ulmus lobel',
#        'Vacant Tree Pit (planned: Acer freemanii )', 'Aesculus indica',
#        'Amelanchier canadensis', 'Tilia olivieri',
#        'Vacant Tree Pit (planned: Pinus nigra)',
#        'Ulmus carpinifolia Wredei Aure',
#        'Vacant Tree Pit (planned: Cornus controversa variegata)',
#        'Tilia tomentosa', 'Ligustrum ovalifolium',
#        'Vacant Tree Pit (planned: Juglans regia)', 'Prunus sargentii',
#        "Laburnum x watereri 'Vossii'", 'Crataegus x prunifolia Splend',
#        'Alnus incana', 'Acer rubrum', 'Laurus nobilis',
#        'Hamamelis intermedia Jelena', 'Malus Tschonoskii',
#        'Prunus unidentified species', 'Quercus palustris Green Pillar',
#        'Viburnum acerifolium',
#        "Vacant Tree Pit (planned: Sorbus aria 'Majestica')",
#        'Nothofagus antarctica', "Malus 'Madresfield Court'",
#        'Acer palmatum',
#        "Vacant Tree Pit (planned: Prunus sargentii 'Rancho')",
#        'Acer cappadocicum', 'Hibiscus syriacus', 'Davidia involucrata',
#        'Sorbus aucuparia Edulis', 'Gleditsia tri Draves Street Ke',
#        'Chamaecyparis unidentified spe', 'Larix x eurolepis',
#        'Cornus kousa chinensis',
#        'Vacant Tree Pit (planned: Pterocarya Fraxinifolia)',
#        "Acer negundo 'Variegatum'", 'Sequoiadendron giganteum',
#        'Betula pubescens', 'Ulmus × hollandica Jacq Hilli',
#        'Vacant Tree Pit (planned: Ostrya carpinifolia)',
#        'Yucca unidentified species', "Sorbus 'Embley'", 'Quercus ilex',
#        'Vacant Tree Pit (planned: Prunus cerasifera)',
#        "Salix alba 'unidentified varie",
#        'Vacant Tree Pit (planned: Nyssa sylvatica)',
#        'Vacant Tree Pit (planned: Liriodendron tulipifera)',
#        'Cupressus sempervirens', "Prunus fruticosa 'Globosum'",
#        'Cornus unidentified species',
#        "Vacant Tree Pit (planned: Acer platanoides 'Emerald Que')",
#        "Populus nigra 'Italica'", 'Prunus padus', 'Magnolia spectrum',
#        'Quercus coccinea', 'Quercus cerris', 'Aesculus pavia',
#        'Malus adirondack', 'Quercus suber', 'Ostrya carpinifolia',
#        "Acer platanoides 'Olmsted'", 'Malus sylvestris', 'Juglans regia',
#        'Eucalyptus gunnii', "Acer pseudoplatanus 'Brilliant",
#        'Acer pseudoplatanus', 'Cornus kousa Milky Way',
#        'Vacant Tree Pit (planned: Amelanchier alnifolia obelisk)',
#        'Ulmus procera', 'Pinus unidentified species',
#        "Vacant Tree Pit (planned: Sorbus aucuparia 'Streetwise')",
#        'Nyssa sylvatica', 'Prunus Snow Goose', 'Acer capillipes',
#        'Halesia monticola', 'Alnus glutinosa', 'Magnolia Susan',
#        'Liquidambar acalyina', 'Prunus serrula',
#        'Vacant Tree Pit (planned: Betula nigra)', 'Sorbus americana',
#        'Acer campestre William Cadwell', 'Acer campestre Queen Elizabeth',
#        'Prunus maackii', "Prunus 'Pink Perfection'", 'Ulmus lutece',
#        'Liquidambar styraciflua Worple',
#        'Vacant Tree Pit (planned: Amelanchier arborea Robin Hill)',
#        'Alnus x spaethii', "Tilia tomentosa 'Petiolaris'",
#        'Sorbus x arnoldiana Schouten', 'Liquidambar styraciflua Palo A',
#        'Vacant Tree Pit (planned: Lagerstroemia indica Rosa Nova)',
#        'Acer campestre Elegant',
#        'Vacant Tree Pit (planned: Betula utilis Edinburgh)',
#        'Ilex x altaclarensis', 'Sorbus aucuparia', 'Magnolia Star Wars',
#        'Koelreuteria paniculata',
#        'Vacant Tree Pit (planned: Salix babylonica)',
#        "Sorbus aria 'Lutescens'", "Prunus avium 'Plena'",
#        "Acer rubrum 'Scanlon'", 'Prunus cerasifera', 'Carpinus japonica',
#        "Prunus subhirtella 'Pendula Pl", "Crataegus laevigata 'Paul's Sc",
#        'Fagus sylvatica', 'Betula pendula Obelisk',
#        'Liquidambar styraciflua Gumbal', "Cornus Eddie's white wonder",
#        "Prunus padus 'Albertii'", 'Prunus lusitanica',
#        'Quercus bimondorum',
#        'Vacant Tree Pit (planned: Halesia carolina)',
#        'Platanus orientalis Minaret', 'Acer japonicum',
#        'Casuarina equisetifolia', "Cornus controversa 'Variegata'",
#        "Ulmus 'Columella'", 'Vacant Tree Pit (planned: Magnolia kobus)',
#        'Ulmus Fiorente', 'Pyrus communis', 'Gleditsia triacanthos',
#        'Vacant Tree Pit (planned: Crataegus X prunifolia)',
#        'Acer lobelii', 'x Cupresocyparis leylandii', 'Malus floribunda',
#        'Picea abies', "Pyrus calleryana 'Chanticclere", "Prunus 'Ichiyo'",
#        "Vacant Tree Pit (planned: Malus 'Everest')",
#        'Eleagnus angustifolia', "Acer campestre 'Streetwise'",
#        'Vacant Tree Pit (planned: Betula jacquemontii)',
#        'Sorbus x thuringiaca', 'Amelanchier arborea Robin Hill',
#        'Cupressus macrocarpa', 'Sophora japonica', 'Vacant Tree Pit',
#        'Hippophae salicifolia ‘Streetw', 'Betula ermanii',
#        'Larix decidua', 'Vacant Tree Pit (planned: Larix x eurolepis)',
#        'Carpinus betulus streetwise',
#        'Vacant Tree Pit (planned: Amelanchier lamarckii)',
#        'Vacant Tree Pit (planned: Sorbus intermedia)',
#        'Vacant Tree Pit (planned: Populus tremula)',
#        'Eriobotrya japonica', "Acer platanoides 'Dissectum'",
#        'Vacant Tree Pit (planned: Carpinus betulus)', "Prunus 'Umineko'",
#        'Ailanthus altissima', 'Ulmus carpinifolia',
#        'Vacant Tree Pit (planned: Platanus orientalis)',
#        'Vacant Tree Pit (planned: Sorbus torminalis)',
#        "Crataegus oxyacantha 'Rosea Fl", "Euonymus europ. 'Red Cascade'",
#        'Vacant Tree Pit (planned: Alnus cordata)', 'Cotoneaster frigidus',
#        "Betula pendula 'Tristis'", 'Picea pungens',
#        "Cedrus atlantica 'Glauca'", 'Tilia europaea',
#        'Populus balsamifera', "Prunus 'Amanogawa'",
#        'Vacant Tree Pit (planned: Juglans nigra)', 'Prunus persica',
#        'Magnolia unidentified species', "Acer rubrum 'October Glory'",
#        'Vacant Tree Pit (planned: Acer campestre)',
#        'Cercis canadensis Forest Pansy', 'Betula albosinensis Fasc.',
#        "Vacant Tree Pit (planned: Crataegas monogyna 'Stricta')",
#        'Aesculus hippocatanum', 'Fagus sylvatica purpurea',
#        'Populus robusta', 'Populus canescens', 'Populus nigra italica',
#        'prunus padus', 'Salix cinerea', 'Tilia platyphyllus',
#        'Quercuis ilex', 'Abies nordmanniana', 'Abies procera',
#        'Larix leptolepsis', 'Larix eurolepsis', 'Picea omorika',
#        'Picea pungens glauca', 'Picea sitchensis', 'Pinus contorta',
#        'Pinus nigra maritima', 'Tsuga heterophylla',
#        'Cupressocyparis leylandii'], dtype=object)

# %% [markdown]
# This data is **qualitative continuous**.

# %%
tree_json["Common Name"].unique()
# Out:
# array(['Hornbeam - European', 'Cherry - Ornamental', 'Lime', None,
#        'Cedar of Lebanon', "Maple - Freeman's", 'Hawthorn - Common',
#        'Vacant Tree Pit (planned: )', 'Whitebeam', 'Tulip Tree',
#        'Bee-bee Tree', 'Rowan', 'Lime - American', 'Monkey Puzzle',
#        'Mulberry - Black', 'Persian Ironwood',
#        'Vacant Tree Pit (planned: Hazel - Witch)',
#        'Oak - Common, Pedunculate',
#        'Vacant Tree Pit (planned: Buckthorn - Sea)', 'Pine - Scots',
#        'Tamarisk', 'Hawthorn', 'Peanut Butter Tree', 'Judas Tree',
#        'Privet - Chinese', "Birch - Young's weeping", 'Ash - Weeping',
#        'Vacant Tree Pit (planned: Maple - Field)', 'Apple - Crab',
#        'Hazel - Corkscrew', 'Almond', 'Holly', 'Sweet Gum',
#        'Poplar -Black', 'Hazel - Common', 'Kapuka', 'Yew', 'Alder - Red',
#        'Birch - Silver', 'Cedar - Atlas',
#        'Vacant Tree Pit (planned: Yellowwood)', 'Cabbage Tree',
#        'Vacant Tree Pit (planned: Hornbeam - European)', 'Dogwood',
#        'Vacant Tree Pit (planned: Maple - Lebanese wild)', 'Cherry',
#        'Vacant Tree Pit (planned: Beech - Common)', 'Unknown',
#        'Birch - Himalayan', 'Birch - Monarch', 'Dawn Redwood',
#        'Crape myrtle', 'Maidenhair', 'Foxglove Tree',
#        'Vacant Tree Pit (planned: Golden Rain Tree)',
#        'Vacant Tree Pit (planned: Spruce - Norway)', 'Maple', 'Willow',
#        'Maple - Lebanese wild', 'Maple - Purple Norway',
#        'Vacant Tree Pit (planned: Apple)', 'Lime - Large-leaved',
#        'Laurustinus', 'Blue Gum', 'Plane - Oriental', 'Stump',
#        'Ash - Weeping narrow-leafed', 'Maple - Norway', 'Maple - Sugar',
#        'Willow - Corkscrew', "Rowan - Vilmorin's", 'Sweet Chestnut',
#        'Caucasian wingnut', 'Vacant Tree Pit (planned: Whitebeam)',
#        'Rowan - Fastigiate', 'Pear', 'Vacant Tree Pit (planned: Rowan)',
#        'Zelkova - Japanese', 'Oak - Patagonian', 'Japanese zelkova',
#        'June berry', 'Laurel - Cherry', 'Juniper', 'Ash - Narrow-leafed',
#        'Olive', 'Vacant Tree Pit (planned: Pear - Chanticclere)',
#        'Catalpa - Northern',
#        'Vacant Tree Pit (planned: Beech - Antarctic)', 'Elm - Wych',
#        'Sycamore - Purple leaved', 'Sycamore', 'Poplar - Silver',
#        'Blackthorn', 'False Acacia', 'Cherry - Rosebud', 'Maple - Red',
#        "Sumach - Stag's horn",
#        "Vacant Tree Pit (planned: Birch - Erman's)", 'Lime - Mongolian',
#        'Vacant Tree Pit (planned: Zelkova - Japanese)',
#        'Juniper - Common', 'Whitebeam - Swedish', 'European nettle',
#        'Apple - Chinese Crab', 'Maple - Silver', 'Kentucky coffeetree',
#        'Maple - Field', 'Rowan - Yellow berried', 'False Acacia - Frisia',
#        'Sycamore - Golden', 'Chokecherry', 'Apple - Purple crab',
#        'Vacant Tree Pit (planned: Birch - Silver)', 'Ash - American',
#        "Hawthorn - Paul's Scarlet", 'Juniper - Stinking', 'Oak - Lucombe',
#        'Spindle tree', 'Hawthorn - Cockspur', 'Willow - White',
#        'Cotoneaster', 'Elm',
#        'Vacant Tree Pit (planned: Cypress - Arizona)',
#        'Sycamore - Purple Leaved',
#        'Vacant Tree Pit (planned: London plane)', "Cherry - Sargent's",
#        'Maple - Globosum Norway', 'Plum - Common',
#        'Vacant Tree Pit (planned: Red Robin)', 'Pine - Corsican',
#        'Vacant Tree Pit (planned: Pear)', 'Rowan - Hubei',
#        'Maple - Variegated Norway', 'Wier maple', 'Magnolia - Kobus',
#        'Vacant Tree Pit (planned: Maidenhair tree)',
#        'Hawthorn - European', 'Plum',
#        'Vacant Tree Pit (planned: Dogwood)',
#        'Sweet Chestnut - Variegated', 'Elm - Dodoens', "Lime - Henry's",
#        'Hackberry', 'Lime - Caucasian', 'Birch - Cut-leaved',
#        'Yew - common', 'Vacant Tree Pit (planned: European nettle)',
#        'Maple - Snakebark',
#        'Vacant Tree Pit (planned: Kentucky coffeetree)', 'Plane - London',
#        'Cypress - Lawson', 'Pear - Weeping leaved', 'Cherry - Cornelian',
#        'Vacant Tree Pit (planned: Apple - Crab)', 'Yew - Irish',
#        'Magnolia', 'Ash - Yellow', 'Oak - Pin', 'Oak - Upright Engish',
#        'Chinese windmill palm', 'Rhododendron - Common',
#        "Maple - Norway 'Goldsworth Purple'", 'Lime - Small-leaved',
#        'Alder - Green', 'Apple', 'Maple - Crimson King Norway',
#        'Maple - Column Norway', 'Birch - Purple', 'Pittosporum',
#        'Maple - Amur', 'Pecan', 'False Acacia - Upright',
#        'Cypress - Arizona', 'Butterfly bush', 'Aspen', 'Paper birch',
#        'Willow - Scarlet', 'Medlar - Common', 'Willow - Weeping',
#        'Vacant Tree Pit (planned: Cherry)', 'Crabapple - Cut-leaf',
#        'Alder - Blue', 'Cherry - Double pint', 'Serviceberry',
#        'Vacant Tree Pit (planned: Judas Tree)', "Rowan - 'Golden Wonder'",
#        'Vacant Tree Pit (planned: False Acacia)', 'Ash',
#        'Mulberry - White', 'Vacant Tree Pit (planned: Japanese Pagoda)',
#        'Alder - Cut leaved', 'Maidenhair tree',
#        'Vacant Tree Pit (planned: Lime - Silver)', 'Plum - Victoria',
#        'Fir - Douglas', 'Cherry - Japanese', 'Golden Indian bean tree',
#        'Elm - Dutch', 'Pine - Bhutan', 'Ash - Manna',
#        'Vacant Tree Pit (planned: Elm)', 'Hornbeam',
#        'Zelkova - Caucasian', 'Fir - Silver', 'Horse Chestnut',
#        'Box Elder - Variegated', 'Horse chestnut - Red',
#        'Maple - Boxelder', 'Beech - Fastigiate', 'Beech - Purple',
#        'Hawthorn - Cockspur thorn', 'Cedar - Deodar',
#        "Horsechestnut - Baumann's", 'Birch', 'June Berry',
#        'Redwood - Coastal', 'Willow - Kilmarnock',
#        'Hawthorn - Broad-leaved cockspur thorn', 'Kumquats',
#        'Cherry - Yoshino', 'Vacant Tree Pit (planned: Sweet Gum)',
#        'Rowan - Japanese', 'Pear - Chanticleer',
#        'Vacant Tree Pit (planned: Magnolia)', 'Cedar - Western Red',
#        'Rowan - Cut leaved', 'Cypress - Bald', 'Lilac', 'Tulip - Upright',
#        'Vacant Tree Pit (planned: Hazel - Turkish)', 'Cypress',
#        'Privet - Wild', 'Spruce',
#        'Vacant Tree Pit (planned: Sweet Chestnut)', 'Hardy Rubber Tree',
#        'Vacant Tree Pit (planned: Hardy Rubber Tree)', 'Gum - Snow',
#        'Rose of Sharon', 'June berry - Upright',
#        'Vacant Tree Pit (planned: Pine - Scots)', 'Mimosa',
#        'Oak - Sessile', 'Vacant Tree Pit (planned: Maple - Red)',
#        'Willow - Crack', 'Red Robin', 'Whitebeam - Tibetan',
#        'Indian Bean Tree', 'Alder - Italian',
#        'Vacant Tree Pit (planned: Indian Bean Tree)', 'Elder',
#        'London plane', 'Fig', 'Hornbeam - Fastigiate European',
#        'Laburnum', 'Birch - River',
#        'Vacant Tree Pit (planned: Dawn Redwood)', 'Cherry - Wild, Gean',
#        "Vacant Tree Pit (planned: Cherry - Sargent's)",
#        'Maple - Paperbark', 'Strawberry tree', 'Flannel Bush',
#        'Horsechestnut - Red',
#        'Vacant Tree Pit (planned: Poplar - Silver)',
#        'Maple - Silver veriegated Norway', 'Willow - Goat',
#        'Lilac - Wild', "Rowan - Sargent's", 'Dogwood - Flowering',
#        'Oak - Chestnut-leaved', 'Walnut - Black', 'Fir - Noble',
#        'Vacant Tree Pit (planned: Persian Ironwood)', 'Hazel - Turkish',
#        'Buckeye - Yellow', 'Mulberry - Paper', 'Ash - One-leaved',
#        'Plum - Purple', 'Oak - Red', 'Cypress - Leyland', "Elm - Lobel's",
#        'Horse chestnut - Indian', 'Serviceberry - Canadian',
#        'Vacant Tree Pit (planned: Pine - Corsican)', 'Elm - Golden',
#        'Vacant Tree Pit (planned: Dogwood - Variegated)', 'Lime - Silver',
#        'Privet - Golden', 'Vacant Tree Pit (planned: Walnut)',
#        'Alder - Grey', 'Bay tree', 'Hazel - Witch',
#        'Viburnum - Mapleleaf', 'Beech - Antarctic', 'Maple - Japanese',
#        'Maple - Caucasian', 'Handkerchief Tree', 'Honey Locust',
#        'Larch - Hybrid', 'Dogwood - Chinese',
#        'Vacant Tree Pit (planned: Caucasian wingnut)', 'Maple - Ashleaf',
#        'Giant Sequoia', 'Birch - Downy, Hairy',
#        'Vacant Tree Pit (planned: Hornbeam - Hop)', 'Yucca',
#        'Rowan - Scarlet', 'Oak - Evergreen, Holm',
#        'Vacant Tree Pit (planned: Plum)',
#        'Vacant Tree Pit (planned: Tupelo)',
#        'Vacant Tree Pit (planned: Tulip Tree)', 'Cypress - Mediterranean',
#        'Cherry - Mop Top', 'Vacant Tree Pit (planned: Maple - Norway)',
#        'Poplar - Lombardy', 'Cherry - Bird', 'Oak - Scarlet',
#        'Oak - Turkey', 'Oak - Cork', 'Hornbeam - Hop',
#        'Maple - Olmstead Norway', 'Walnut', 'Gum - Cider',
#        'Sycamore - Brillianissiumum',
#        'Vacant Tree Pit (planned: June berry - Upright)', 'Elm - English',
#        'Pine', 'Vacant Tree Pit (planned: Mountain-ash)', 'Tupelo',
#        'Apple - Snakebark', 'Alder - Common', 'Sweetgum',
#        'Cherry - Tibetan', 'Vacant Tree Pit (planned: Birch - River)',
#        'Rowan - American', 'Cherry - Manchurian',
#        'Vacant Tree Pit (planned: June berry)', 'Alder - Spaeth',
#        'Lime - Weeping silver', 'Vacant Tree Pit (planned: Crape myrtle)',
#        'Rowan, Mountain Ash', 'Golden Rain Tree',
#        'Vacant Tree Pit (planned: Willow - Weeping)',
#        'Cherry - Double white', 'Maple - Canadian', 'Hornbeam - Japanese',
#        'Cherry - Weeping', 'Hawthorn - Red', 'Beech - Common',
#        'Weeping silver birch', 'Sweetgum - Gumball', 'Laurel - Portugese',
#        'Oak - Two World', 'Pine - Australian',
#        'Vacant Tree Pit (planned: Magnolia - Kobus)',
#        'Vacant Tree Pit (planned: Hawthorn)', "Maple - Lobel's",
#        'Spruce - Norway', 'Pear - Chanticclere',
#        'Vacant Tree Pit (planned: Birch - Himalayan)',
#        'Cypress - Monterey', 'Japanese Pagoda', 'Vacant Tree Pit',
#        'Buckthorn - Sea', "Birch - Erman's", 'Larch - European',
#        'Vacant Tree Pit (planned: Larch - Hybrid)', 'Hornbeam - Common',
#        'Vacant Tree Pit (planned: June Berry)',
#        'Vacant Tree Pit (planned: Whitebeam - Swedish)',
#        'Vacant Tree Pit (planned: Aspen)', 'Loquat',
#        'Vacant Tree Pit (planned: Hornbeam)', 'Tree of Heaven',
#        'Elm - Smoothleaf', 'Vacant Tree Pit (planned: Plane - Oriental)',
#        'Hawthorn - Double pink',
#        'Vacant Tree Pit (planned: Alder - Italian)',
#        'Birch - Weeping silver', 'Spruce - Colorado', 'Lime - Common',
#        'Poplar - Balsam', 'Vacant Tree Pit (planned: Walnut - Black)',
#        'Peach', 'Redbud - Eastern', 'Birch - Chinese Red', 'Field maple',
#        'Norway maple', 'Horse chestnut', 'Italian alder', 'Common alder',
#        'Grey alder', 'Silver birch', 'Downy birch', 'Sweet chestnut',
#        'Beech', 'Copper Beech', 'Crab apple', 'Hybrid poplar',
#        'Grey poplar', 'White poplar', 'Black poplar', 'Lombardy poplar',
#        'Wild cherry', 'Bird cherry', 'Sessile oak', 'English oak',
#        'Red oak', 'White willow', 'Goat willow', 'Grey willow',
#        'Crack willow', 'Swedish Whitebeam', 'Small leaved Lime',
#        'Broad leaved Lime', 'Evergreen oak', 'Nordman’s fir', 'Noble fir',
#        'Lawson’s cypress', 'European larch', 'Japanese larch',
#        'Hybrid larch', 'Norway spruce', 'Serbian spruce', 'Blue spruce',
#        'Sitka spruce', 'Contorta pine', 'Corsican pine', 'Scots pine',
#        'Western red cedar', 'Western Hemlock', 'Leylandii green',
#        'Castlewellan gold'], dtype=object)

# %% [markdown]
# This data is **qualitative continuous**.

# %% [markdown]
# <hr/>

# %% [markdown]
# #### 3.3.b (Names) Descriptive Stats for Numeric Type Columns
# There are no numeric columns.

# %% [markdown]
# ## Task 4: Identify Missing Values
# Find the number of missing values in each column.  Missing values can indicate data quality issues.  Missing are nulls in our data.  But sometimes zero values indicate missing values.  For example, a zero value for a tree height is clearly not a valid valid, so should be considered missing.
#
# Use these functions to find rows that have missing and zero values:
#
# - [pandas.DataFrame.isnull](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isnull.html)
# - [pandas.DataFrame.isin](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isin.html)
# - [pandas.DataFrame.mean](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html)
# - [pandas.DataFrame.sum](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sum.html)
#
# As you go through this task, think about the possible impact of the missing values on the ability of the data to deliver on the council's initiatives.  There is no absolute answer to "how many missing values is too many".  It depends on the context of what you intend to do with the data.  Try to make an interpretation based on your understanding of the requirements.

# %% [markdown]
# ### 4.1 Missing Values for the Trees Dataset
# I've shown you how to do this for the trees dataset.

# %%
# Percentage of null values
trees.isnull().mean()*100
# Out:
# Identifier                                  0.000000
# Number Of Trees                             0.093841
# Site Name                                   0.000000
# Contract Area                               0.000000
# Scientific Name                             0.000000
# Inspection Date                             1.710459
# Inspection Due Date                         1.710459
# Height In Metres                            1.868282
# Spread In Metres                            1.868282
# Diameter In Centimetres At Breast Height    1.872547
# Ward Code                                   0.963999
# Ward Name                                   0.963999
# Easting                                     0.000000
# Northing                                    0.000000
# Longitude                                   0.238867
# Latitude                                    0.238867
# Location                                    0.238867
# dtype: float64

# %%
# Number of null values
trees.isnull().sum()
# Out:
# Identifier                                    0
# Number Of Trees                              22
# Site Name                                     0
# Contract Area                                 0
# Scientific Name                               0
# Inspection Date                             401
# Inspection Due Date                         401
# Height In Metres                            438
# Spread In Metres                            438
# Diameter In Centimetres At Breast Height    439
# Ward Code                                   226
# Ward Name                                   226
# Easting                                       0
# Northing                                      0
# Longitude                                    56
# Latitude                                     56
# Location                                     56
# dtype: int64

# %%
# Percentage of zero values
trees.isin([0]).mean()*100
# Out:
# Identifier                                  0.000000
# Number Of Trees                             0.396690
# Site Name                                   0.000000
# Contract Area                               0.000000
# Scientific Name                             0.000000
# Inspection Date                             0.000000
# Inspection Due Date                         0.000000
# Height In Metres                            0.733663
# Spread In Metres                            1.181539
# Diameter In Centimetres At Breast Height    1.164477
# Ward Code                                   0.000000
# Ward Name                                   0.000000
# Easting                                     0.238867
# Northing                                    0.238867
# Longitude                                   0.000000
# Latitude                                    0.000000
# Location                                    0.000000
# dtype: float64

# %%
# Number of zero values
trees.isin([0]).sum()
# Out:
# Identifier                                    0
# Number Of Trees                              93
# Site Name                                     0
# Contract Area                                 0
# Scientific Name                               0
# Inspection Date                               0
# Inspection Due Date                           0
# Height In Metres                            172
# Spread In Metres                            277
# Diameter In Centimetres At Breast Height    273
# Ward Code                                     0
# Ward Name                                     0
# Easting                                      56
# Northing                                     56
# Longitude                                     0
# Latitude                                      0
# Location                                      0
# dtype: int64

# %%
# Percentage of null and zero values
(trees.isnull().sum() + trees.isin([0]).sum())/trees.shape[0]
# Out:
# Identifier                                  0.000000
# Number Of Trees                             0.004905
# Site Name                                   0.000000
# Contract Area                               0.000000
# Scientific Name                             0.000000
# Inspection Date                             0.017105
# Inspection Due Date                         0.017105
# Height In Metres                            0.026019
# Spread In Metres                            0.030498
# Diameter In Centimetres At Breast Height    0.030370
# Ward Code                                   0.009640
# Ward Name                                   0.009640
# Easting                                     0.002389
# Northing                                    0.002389
# Longitude                                   0.002389
# Latitude                                    0.002389
# Location                                    0.002389
# dtype: float64

# %%
# Number of null and zero values
(trees.isnull().sum() + trees.isin([0]).sum())
# Out:
# Identifier                                    0
# Number Of Trees                             115
# Site Name                                     0
# Contract Area                                 0
# Scientific Name                               0
# Inspection Date                             401
# Inspection Due Date                         401
# Height In Metres                            610
# Spread In Metres                            715
# Diameter In Centimetres At Breast Height    712
# Ward Code                                   226
# Ward Name                                   226
# Easting                                      56
# Northing                                     56
# Longitude                                    56
# Latitude                                     56
# Location                                     56
# dtype: int64

# %% [markdown]
# ### Missing Values for the Environmental Dataset
# Repeated the missing values check for the environmental dataset.

# %%
# Percentage of null values
trees_cvs_file.isnull().mean()*100
# Out:
# Identifier                                           0.000000
# Maturity                                             1.746744
# Physiological Condition                              2.015802
# Tree Set To Be Removed                               0.000000
# Removal Reason                                      99.641256
# Capital Asset Value For Amenity Trees                1.849242
# Carbon Storage In Kilograms                         12.214392
# Gross Carbon Sequestration Per Year In Kilograms    12.214392
# Pollution Removal Per Year In Grams                 12.214392
# dtype: float64

# %%
# Number of null values
trees_cvs_file.isnull().sum()
# Out:
# Identifier                                              0
# Maturity                                              409
# Physiological Condition                               472
# Tree Set To Be Removed                                  0
# Removal Reason                                      23331
# Capital Asset Value For Amenity Trees                 433
# Carbon Storage In Kilograms                          2860
# Gross Carbon Sequestration Per Year In Kilograms     2860
# Pollution Removal Per Year In Grams                  2860
# dtype: int64

# %%
# Percentage of zero values
trees_cvs_file.isin([0]).mean()*100
# Out:
# Identifier                                          0.000000
# Maturity                                            0.000000
# Physiological Condition                             0.000000
# Tree Set To Be Removed                              0.000000
# Removal Reason                                      0.000000
# Capital Asset Value For Amenity Trees               1.183002
# Carbon Storage In Kilograms                         0.000000
# Gross Carbon Sequestration Per Year In Kilograms    0.025625
# Pollution Removal Per Year In Grams                 0.000000
# dtype: float64

# %%
# Number of zero values
trees_cvs_file.isin([0]).sum()
# Out:
# Identifier                                            0
# Maturity                                              0
# Physiological Condition                               0
# Tree Set To Be Removed                                0
# Removal Reason                                        0
# Capital Asset Value For Amenity Trees               277
# Carbon Storage In Kilograms                           0
# Gross Carbon Sequestration Per Year In Kilograms      6
# Pollution Removal Per Year In Grams                   0
# dtype: int64

# %%
# Percentage of null and zero values
(trees_cvs_file.isnull().sum() + trees_cvs_file.isin([0]).sum())/trees_cvs_file.shape[0]
# Out:
# Identifier                                          0.000000
# Maturity                                            0.017467
# Physiological Condition                             0.020158
# Tree Set To Be Removed                              0.000000
# Removal Reason                                      0.996413
# Capital Asset Value For Amenity Trees               0.030322
# Carbon Storage In Kilograms                         0.122144
# Gross Carbon Sequestration Per Year In Kilograms    0.122400
# Pollution Removal Per Year In Grams                 0.122144
# dtype: float64

# %%
# Number of null and zero values
(trees_cvs_file.isnull().sum() + trees_cvs_file.isin([0]).sum())
# Out:
# Identifier                                              0
# Maturity                                              409
# Physiological Condition                               472
# Tree Set To Be Removed                                  0
# Removal Reason                                      23331
# Capital Asset Value For Amenity Trees                 710
# Carbon Storage In Kilograms                          2860
# Gross Carbon Sequestration Per Year In Kilograms     2866
# Pollution Removal Per Year In Grams                  2860
# dtype: int64

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 4.3 Missing Values for the Common Names Dataset
# Now repeat the missing values check for the common names dataset.

# %%
tree_json.isnull().mean()*100
# Out:
# Scientific Name    0.000000
# Common Name        4.074703
# dtype: float64

# %%
tree_json.isnull().sum()
# Out:
# Scientific Name     0
# Common Name        24
# dtype: int64

# %%
tree_json.isin([0]).mean()*100
# Out:
# Scientific Name    0.0
# Common Name        0.0
# dtype: float64

# %%
tree_json.isin([0]).sum()
# Out:
# Scientific Name    0
# Common Name        0
# dtype: int64

# %%
(tree_json.isnull().sum() + tree_json.isin([0]).sum())/tree_json.shape[0]
# Out:
# Scientific Name    0.000000
# Common Name        0.040747
# dtype: float64

# %%
(tree_json.isnull().sum() + tree_json.isin([0]).sum())
# Out:
# Scientific Name     0
# Common Name        24
# dtype: int64

# %% [markdown]
# <hr/>
#
# ### 4.4 Observations

# %% [markdown]
# There is a lot of missing data null data. I have provided some exampes
# - 401 trees are missing inspect dates and due dates.
# - 480 trees are missing spread and height.
# - 226 trees are missing ward code and ward name.
# - 56 trees are missing latitude, longitude and location.
# - 227 trees are missing their Capital Asset Value For Amenity.
# - There are 24 trees that don't have their matching scientific names.
#
# This would impact the initiatives that the council would like to propose as the many missing values in the trees data will cause the data to be incomplete. There is also a large amount of missing data in the environmental dataset.

# %% [markdown]
# <hr/>

# %% [markdown]
# ## Task 5: Identify Outliers in the Trees Dimensions
# Outliers are values that are so unusual they are possibly incorrect!  We can use a boxplot to show the spread of data and any outliers.  Read the following section if you are unfamiliar with them:
#
# - [Box plots](https://openclassrooms.com/en/courses/6037301-perform-an-initial-data-analysis/6052306-calculate-the-value-spread-in-your-data#/id/r-6133902)
#
# Any circles represent what the boxplot considers outliers, but some of these might just be correct but extreme values.  We want to only highlight really *crazy* values which are clearly incorrect.
#
# We can use this function to draw boxplots:
#
# - [pandas.DataFrame.boxplot](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html)
#
# Once we have found if there are outliers, it would be nice to show the rows containing the outliers.  The technique for filtering Pandas DataFrames is described here:
#
# - [Filtering Pandas DataFrames](https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/03_subset_data.html)
#
# The filtering technique creates a mask of rows that we want to select, e.g:
#
# `mask = df['mycolumn'] > 500`
#
# and then uses the mask to select rows:
#
# `df[mask]`
#
# Note that there is no absolute definition of what "crazy" means here.  You will need to make some judgements based on your understanding of the world (or specifically the world of trees in Camden!).

# %% [markdown]
# ### 5.1 Outliers for Height
# Find the outliers in the tree height column.

# %%
trees.columns
# Out:
# Index(['Identifier', 'Number Of Trees', 'Site Name', 'Contract Area',
#        'Scientific Name', 'Inspection Date', 'Inspection Due Date',
#        'Height In Metres', 'Spread In Metres',
#        'Diameter In Centimetres At Breast Height', 'Ward Code', 'Ward Name',
#        'Easting', 'Northing', 'Longitude', 'Latitude', 'Location'],
#       dtype='object')

# %%
trees['Height In Metres'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# trees['Height In Metres'].plot(kind='box')

# %%
# Select the crazy outlier rows
mask = trees['Height In Metres'] > 80
trees[mask]
# Out:
#      Identifier  Number Of Trees               Site Name Contract Area  \
# 1356   00001547              1.0    Beaumont Walk Estate       Housing
# 1863   00013862              1.0  Maitland Park Estate 1       Housing
#
#            Scientific Name Inspection Date Inspection Due Date  \
# 1356  Robinia pseudoacacia      2017-05-23           2020/2021
# 1863          Prunus avium      2017-05-16           2020/2021
#
#       Height In Metres  Spread In Metres  \
# 1356              96.0              10.0
# 1863             127.0               9.0
#
#       Diameter In Centimetres At Breast Height  Ward Code   Ward Name  \
# 1356                                      63.0  E05000136  Haverstock
# 1863                                      34.0  E05000136  Haverstock
#
#       Easting  Northing  Longitude   Latitude                Location
# 1356   527847    184391  -0.157739  51.543941  (51.543941, -0.157739)
# 1863   527987    184901  -0.155534  51.548497  (51.548497, -0.155534)

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 5.2 Outliers for Spread
# Now repeat the analysis for spread.

# %%
# Use a boxplot to find the outliers
trees['Spread In Metres'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# Select the crazy outlier rows (if any)
mask = trees['Spread In Metres'] > 80
trees[mask]
# Out:
#       Identifier  Number Of Trees            Site Name Contract Area  \
# 18567   00045515              1.0  Broadfield Estate 1       Housing
#
#       Scientific Name Inspection Date Inspection Due Date  Height In Metres  \
# 18567   Quercus robur      2018-04-26           2021/2022               8.0
#
#        Spread In Metres  Diameter In Centimetres At Breast Height  Ward Code  \
# 18567              88.0                                      17.0  E05000144
#
#            Ward Name  Easting  Northing  Longitude   Latitude  \
# 18567  Swiss Cottage   525993    184693  -0.184348  51.547074
#
#                      Location
# 18567  (51.547074, -0.184348)

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 5.3 Outliers for Diameter
# Now repeat the analysis for diameter.

# %%
# Use a boxplot to find the outliers
trees['Diameter In Centimetres At Breast Height'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# Select the outlier rows (if any)
# No outliers

# %% [markdown]
# <hr/>
#
# ### 5.4 Observations

# %% [markdown]
# I made assumptions based on the far data some of the data had with the other data that were all relatively clumped together. I assumed those to be the crazy outliers.
# There are two crazy outliers in 'Height In Metres'.
# There is one crazy outlier in 'Spread In Metres'.
# For the 'Diameter In Centimetres At Breast Height' boxplot, I assumed there to be no crazy outliers as the gap wasn't large enough.

# %% [markdown]
# <hr/>

# %% [markdown]
# ## Task 6: Identifying Duplicates in the Trees Dataset
# Sometimes data has duplicate entries.  This is another sign of data quality issues!
#
# ### 6.1 Find Duplicate Rows
#
# In our dataset the `Identifier` column should be unique.  Find out if it is!  We've already used a function that can count how many times each value in a column exists.  Use is to see if we have duplicates in the trees Dataframe.

# %%
id_counts = trees["Identifier"].value_counts()
id_counts[id_counts>1]
# Out:
# 00000999    2
# 00060087    2
# 00022744    2
# 00032549    2
# 00022674    2
# 00060088    2
# Name: Identifier, dtype: int64

# %% [markdown]
# Now see if you can select the rows from trees DataFrame that are duplicates.  You will need to use the output from the cell above and use it to filter the trees dataframe.

# %%
mask = trees["Identifier"].isin(id_counts[id_counts>1].index)
trees[mask].shape
# Out:
# (12, 17)

# %% [markdown]
# <hr/>
#
# ### 6.2 Observations

# %% [markdown]
# 12 tree data columns are duplicated

# %% [markdown]
# <hr/>

# %% [markdown]
# ## Task 7: Identify Geolocation Issues
# The geographic coordinates (Easting and Northing) can be used to plot the trees on a map.  We can use this approach to see if there are any unusual tree locations!
#
# We will make a copy of the original trees dataset and remove any rows that have a missing easting or northing as these can't be plotted on the map.
#
# We can copy the DataFrame using:
#
# - [pandas.DataFrame.copy](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html)
#
# We can use the DataFrame filtering technique we saw before to remove the missing values.  E.g. the following code filters out rows where the value for 'mycolumn' is 100:
#
#     mask = df['mycolumn'] != 100
#     df = df[mask]
#
# You can also create masks using a function, e.g. this creates a mask which excludes nulls:
#
#     mask = df['mycolumn'].isnull()
#
# We can use this function to plot the trees on a map. Set x to "Easting" and y to "Northing" and set a figsize parameter to (6, 6) to get a square aspect ratio:
#
# - [pandas.DataFrame.plot.scatter](https://pandas.pydata.org/pandas-docs/version/0.25.0/reference/api/pandas.DataFrame.plot.scatter.html)

# %% [markdown]
# ### 7.1 Remove Trees with Missing Geo-coordinates
# Check if there are any rows with null or 0 geo-coordinates.  If there are, remove them as we can't plot these.

# %%
# Make a copy of the trees
geotrees = trees.copy()

# %%
geotrees.columns
# Out:
# Index(['Identifier', 'Number Of Trees', 'Site Name', 'Contract Area',
#        'Scientific Name', 'Inspection Date', 'Inspection Due Date',
#        'Height In Metres', 'Spread In Metres',
#        'Diameter In Centimetres At Breast Height', 'Ward Code', 'Ward Name',
#        'Easting', 'Northing', 'Longitude', 'Latitude', 'Location'],
#       dtype='object')

# %%
# Remove null Eastings
geotrees.dropna(subset=['Easting'])
# Out:
#       Identifier  Number Of Trees                         Site Name  \
# 0       00060053              1.0          Russell Nurseries Estate
# 1       00057855              1.0                 BRECKNOCK JMI (E)
# 2       00059953              1.0        Estate 51 Ravenshaw Street
# 3       00059915              1.0                 ROSARY RC JMI (E)
# 4       00010762              1.0                Holly Lodge Estate
# ...          ...              ...                               ...
# 23439   00057455              1.0  KILBURN GRANGE, MESSINA AVE (LS)
# 23440   00015494              1.0                  OSSULSTON STREET
# 23441   00001693              1.0                    BELMONT STREET
# 23442   00020342              1.0              Templar House Estate
# 23443   00013369              1.0                    LYNDHURST ROAD
#
#       Contract Area          Scientific Name Inspection Date  \
# 0           Housing          Vacant Tree Pit             NaT
# 1         Education          Vacant Tree Pit      2019-07-17
# 2           Housing             Ficus carica             NaT
# 3         Education      Betula jacquemontii             NaT
# 4           Housing     Ilex x altaclarensis      2017-06-14
# ...             ...                      ...             ...
# 23439         Parks              Sorbus aria      2017-03-28
# 23440      Highways  Sorbus aria 'Majestica'      2019-10-28
# 23441      Highways     Platanus x hispanica      2017-07-31
# 23442       Housing           Tilia europaea      2018-11-05
# 23443      Highways           Tilia europaea      2018-06-08
#
#       Inspection Due Date  Height In Metres  Spread In Metres  \
# 0                     NaN               NaN               NaN
# 1               2022/2023               NaN               NaN
# 2                     NaN               5.0               4.0
# 3                     NaN               4.0               1.0
# 4               2020/2021              14.0               6.0
# ...                   ...               ...               ...
# 23439           2019/2020               2.0               1.0
# 23440           2022/2023              12.0               6.0
# 23441           2020/2021              18.0              10.0
# 23442           2021/2022              20.0               8.0
# 23443           2021/2022              15.0               6.0
#
#        Diameter In Centimetres At Breast Height  Ward Code  \
# 0                                           NaN  E05000135
# 1                                           NaN  E05000131
# 2                                          10.0        NaN
# 3                                           6.0  E05000135
# 4                                          26.0  E05000137
# ...                                         ...        ...
# 23439                                       6.0  E05000140
# 23440                                      48.0  E05000143
# 23441                                      57.0  E05000136
# 23442                                      40.0  E05000132
# 23443                                      77.0  E05000135
#
#                         Ward Name  Easting  Northing  Longitude   Latitude  \
# 0                  Hampstead Town   527305    185240  -0.165240  51.551693
# 1                      Cantelowes   529923    184782  -0.127681  51.546984
# 2                             NaN        0         0        NaN        NaN
# 3                  Hampstead Town   527249    185261  -0.166051  51.551901
# 4                        Highgate   528414    186770  -0.148704  51.565198
# ...                           ...      ...       ...        ...        ...
# 23439                     Kilburn   525130    184418  -0.196884  51.544796
# 23440  St Pancras and Somers Town   529758    183095  -0.130667  51.531863
# 23441                  Haverstock   528302    184457  -0.151163  51.544432
# 23442               Fortune Green   524615    184714  -0.204206  51.547573
# 23443              Hampstead Town   526738    185304  -0.173397  51.552397
#
#                      Location
# 0       (51.551693, -0.16524)
# 1      (51.546984, -0.127681)
# 2                         NaN
# 3      (51.551901, -0.166051)
# 4      (51.565198, -0.148704)
# ...                       ...
# 23439  (51.544796, -0.196884)
# 23440  (51.531863, -0.130667)
# 23441  (51.544432, -0.151163)
# 23442  (51.547573, -0.204206)
# 23443  (51.552397, -0.173397)
#
# [23444 rows x 17 columns]

# %%
# Remove 0 Eastings.  
geotrees[geotrees["Easting"] != 0]
# Out:
#       Identifier  Number Of Trees                         Site Name  \
# 0       00060053              1.0          Russell Nurseries Estate
# 1       00057855              1.0                 BRECKNOCK JMI (E)
# 3       00059915              1.0                 ROSARY RC JMI (E)
# 4       00010762              1.0                Holly Lodge Estate
# 5       00007523              1.0                Westcroft Estate 1
# ...          ...              ...                               ...
# 23439   00057455              1.0  KILBURN GRANGE, MESSINA AVE (LS)
# 23440   00015494              1.0                  OSSULSTON STREET
# 23441   00001693              1.0                    BELMONT STREET
# 23442   00020342              1.0              Templar House Estate
# 23443   00013369              1.0                    LYNDHURST ROAD
#
#       Contract Area          Scientific Name Inspection Date  \
# 0           Housing          Vacant Tree Pit             NaT
# 1         Education          Vacant Tree Pit      2019-07-17
# 3         Education      Betula jacquemontii             NaT
# 4           Housing     Ilex x altaclarensis      2017-06-14
# 5           Housing           Betula pendula      2018-08-06
# ...             ...                      ...             ...
# 23439         Parks              Sorbus aria      2017-03-28
# 23440      Highways  Sorbus aria 'Majestica'      2019-10-28
# 23441      Highways     Platanus x hispanica      2017-07-31
# 23442       Housing           Tilia europaea      2018-11-05
# 23443      Highways           Tilia europaea      2018-06-08
#
#       Inspection Due Date  Height In Metres  Spread In Metres  \
# 0                     NaN               NaN               NaN
# 1               2022/2023               NaN               NaN
# 3                     NaN               4.0               1.0
# 4               2020/2021              14.0               6.0
# 5               2021/2022               9.0               7.0
# ...                   ...               ...               ...
# 23439           2019/2020               2.0               1.0
# 23440           2022/2023              12.0               6.0
# 23441           2020/2021              18.0              10.0
# 23442           2021/2022              20.0               8.0
# 23443           2021/2022              15.0               6.0
#
#        Diameter In Centimetres At Breast Height  Ward Code  \
# 0                                           NaN  E05000135
# 1                                           NaN  E05000131
# 3                                           6.0  E05000135
# 4                                          26.0  E05000137
# 5                                          29.0        NaN
# ...                                         ...        ...
# 23439                                       6.0  E05000140
# 23440                                      48.0  E05000143
# 23441                                      57.0  E05000136
# 23442                                      40.0  E05000132
# 23443                                      77.0  E05000135
#
#                         Ward Name  Easting  Northing  Longitude   Latitude  \
# 0                  Hampstead Town   527305    185240  -0.165240  51.551693
# 1                      Cantelowes   529923    184782  -0.127681  51.546984
# 3                  Hampstead Town   527249    185261  -0.166051  51.551901
# 4                        Highgate   528414    186770  -0.148704  51.565198
# 5                             NaN   524253    185982  -0.208975  51.559049
# ...                           ...      ...       ...        ...        ...
# 23439                     Kilburn   525130    184418  -0.196884  51.544796
# 23440  St Pancras and Somers Town   529758    183095  -0.130667  51.531863
# 23441                  Haverstock   528302    184457  -0.151163  51.544432
# 23442               Fortune Green   524615    184714  -0.204206  51.547573
# 23443              Hampstead Town   526738    185304  -0.173397  51.552397
#
#                      Location
# 0       (51.551693, -0.16524)
# 1      (51.546984, -0.127681)
# 3      (51.551901, -0.166051)
# 4      (51.565198, -0.148704)
# 5      (51.559049, -0.208975)
# ...                       ...
# 23439  (51.544796, -0.196884)
# 23440  (51.531863, -0.130667)
# 23441  (51.544432, -0.151163)
# 23442  (51.547573, -0.204206)
# 23443  (51.552397, -0.173397)
#
# [23388 rows x 17 columns]

# %%
# Remove null Northings
geotrees.dropna(subset=['Northing'])
# Out:
#       Identifier  Number Of Trees                         Site Name  \
# 0       00060053              1.0          Russell Nurseries Estate
# 1       00057855              1.0                 BRECKNOCK JMI (E)
# 2       00059953              1.0        Estate 51 Ravenshaw Street
# 3       00059915              1.0                 ROSARY RC JMI (E)
# 4       00010762              1.0                Holly Lodge Estate
# ...          ...              ...                               ...
# 23439   00057455              1.0  KILBURN GRANGE, MESSINA AVE (LS)
# 23440   00015494              1.0                  OSSULSTON STREET
# 23441   00001693              1.0                    BELMONT STREET
# 23442   00020342              1.0              Templar House Estate
# 23443   00013369              1.0                    LYNDHURST ROAD
#
#       Contract Area          Scientific Name Inspection Date  \
# 0           Housing          Vacant Tree Pit             NaT
# 1         Education          Vacant Tree Pit      2019-07-17
# 2           Housing             Ficus carica             NaT
# 3         Education      Betula jacquemontii             NaT
# 4           Housing     Ilex x altaclarensis      2017-06-14
# ...             ...                      ...             ...
# 23439         Parks              Sorbus aria      2017-03-28
# 23440      Highways  Sorbus aria 'Majestica'      2019-10-28
# 23441      Highways     Platanus x hispanica      2017-07-31
# 23442       Housing           Tilia europaea      2018-11-05
# 23443      Highways           Tilia europaea      2018-06-08
#
#       Inspection Due Date  Height In Metres  Spread In Metres  \
# 0                     NaN               NaN               NaN
# 1               2022/2023               NaN               NaN
# 2                     NaN               5.0               4.0
# 3                     NaN               4.0               1.0
# 4               2020/2021              14.0               6.0
# ...                   ...               ...               ...
# 23439           2019/2020               2.0               1.0
# 23440           2022/2023              12.0               6.0
# 23441           2020/2021              18.0              10.0
# 23442           2021/2022              20.0               8.0
# 23443           2021/2022              15.0               6.0
#
#        Diameter In Centimetres At Breast Height  Ward Code  \
# 0                                           NaN  E05000135
# 1                                           NaN  E05000131
# 2                                          10.0        NaN
# 3                                           6.0  E05000135
# 4                                          26.0  E05000137
# ...                                         ...        ...
# 23439                                       6.0  E05000140
# 23440                                      48.0  E05000143
# 23441                                      57.0  E05000136
# 23442                                      40.0  E05000132
# 23443                                      77.0  E05000135
#
#                         Ward Name  Easting  Northing  Longitude   Latitude  \
# 0                  Hampstead Town   527305    185240  -0.165240  51.551693
# 1                      Cantelowes   529923    184782  -0.127681  51.546984
# 2                             NaN        0         0        NaN        NaN
# 3                  Hampstead Town   527249    185261  -0.166051  51.551901
# 4                        Highgate   528414    186770  -0.148704  51.565198
# ...                           ...      ...       ...        ...        ...
# 23439                     Kilburn   525130    184418  -0.196884  51.544796
# 23440  St Pancras and Somers Town   529758    183095  -0.130667  51.531863
# 23441                  Haverstock   528302    184457  -0.151163  51.544432
# 23442               Fortune Green   524615    184714  -0.204206  51.547573
# 23443              Hampstead Town   526738    185304  -0.173397  51.552397
#
#                      Location
# 0       (51.551693, -0.16524)
# 1      (51.546984, -0.127681)
# 2                         NaN
# 3      (51.551901, -0.166051)
# 4      (51.565198, -0.148704)
# ...                       ...
# 23439  (51.544796, -0.196884)
# 23440  (51.531863, -0.130667)
# 23441  (51.544432, -0.151163)
# 23442  (51.547573, -0.204206)
# 23443  (51.552397, -0.173397)
#
# [23444 rows x 17 columns]

# %%
# Remove 0 Northings.  
geotrees[geotrees["Northing"] != 0]
# Out:
#       Identifier  Number Of Trees                         Site Name  \
# 0       00060053              1.0          Russell Nurseries Estate
# 1       00057855              1.0                 BRECKNOCK JMI (E)
# 3       00059915              1.0                 ROSARY RC JMI (E)
# 4       00010762              1.0                Holly Lodge Estate
# 5       00007523              1.0                Westcroft Estate 1
# ...          ...              ...                               ...
# 23439   00057455              1.0  KILBURN GRANGE, MESSINA AVE (LS)
# 23440   00015494              1.0                  OSSULSTON STREET
# 23441   00001693              1.0                    BELMONT STREET
# 23442   00020342              1.0              Templar House Estate
# 23443   00013369              1.0                    LYNDHURST ROAD
#
#       Contract Area          Scientific Name Inspection Date  \
# 0           Housing          Vacant Tree Pit             NaT
# 1         Education          Vacant Tree Pit      2019-07-17
# 3         Education      Betula jacquemontii             NaT
# 4           Housing     Ilex x altaclarensis      2017-06-14
# 5           Housing           Betula pendula      2018-08-06
# ...             ...                      ...             ...
# 23439         Parks              Sorbus aria      2017-03-28
# 23440      Highways  Sorbus aria 'Majestica'      2019-10-28
# 23441      Highways     Platanus x hispanica      2017-07-31
# 23442       Housing           Tilia europaea      2018-11-05
# 23443      Highways           Tilia europaea      2018-06-08
#
#       Inspection Due Date  Height In Metres  Spread In Metres  \
# 0                     NaN               NaN               NaN
# 1               2022/2023               NaN               NaN
# 3                     NaN               4.0               1.0
# 4               2020/2021              14.0               6.0
# 5               2021/2022               9.0               7.0
# ...                   ...               ...               ...
# 23439           2019/2020               2.0               1.0
# 23440           2022/2023              12.0               6.0
# 23441           2020/2021              18.0              10.0
# 23442           2021/2022              20.0               8.0
# 23443           2021/2022              15.0               6.0
#
#        Diameter In Centimetres At Breast Height  Ward Code  \
# 0                                           NaN  E05000135
# 1                                           NaN  E05000131
# 3                                           6.0  E05000135
# 4                                          26.0  E05000137
# 5                                          29.0        NaN
# ...                                         ...        ...
# 23439                                       6.0  E05000140
# 23440                                      48.0  E05000143
# 23441                                      57.0  E05000136
# 23442                                      40.0  E05000132
# 23443                                      77.0  E05000135
#
#                         Ward Name  Easting  Northing  Longitude   Latitude  \
# 0                  Hampstead Town   527305    185240  -0.165240  51.551693
# 1                      Cantelowes   529923    184782  -0.127681  51.546984
# 3                  Hampstead Town   527249    185261  -0.166051  51.551901
# 4                        Highgate   528414    186770  -0.148704  51.565198
# 5                             NaN   524253    185982  -0.208975  51.559049
# ...                           ...      ...       ...        ...        ...
# 23439                     Kilburn   525130    184418  -0.196884  51.544796
# 23440  St Pancras and Somers Town   529758    183095  -0.130667  51.531863
# 23441                  Haverstock   528302    184457  -0.151163  51.544432
# 23442               Fortune Green   524615    184714  -0.204206  51.547573
# 23443              Hampstead Town   526738    185304  -0.173397  51.552397
#
#                      Location
# 0       (51.551693, -0.16524)
# 1      (51.546984, -0.127681)
# 3      (51.551901, -0.166051)
# 4      (51.565198, -0.148704)
# 5      (51.559049, -0.208975)
# ...                       ...
# 23439  (51.544796, -0.196884)
# 23440  (51.531863, -0.130667)
# 23441  (51.544432, -0.151163)
# 23442  (51.547573, -0.204206)
# 23443  (51.552397, -0.173397)
#
# [23388 rows x 17 columns]

# %%
# Confirm how many rows we have
geotrees.shape
# Out:
# (23444, 17)

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 7.2 Plot Map of Trees
# Now make the plot.  Do a scatter plot of Northing vs Easting. You should obtain an outline of the map of Camden. Compare that outline with a real map of Camden (use good old google maps!). You’ll be able to spot the trees that should not be in that dataset from there!

# %%
# Re ran this code as 0 values were still on the map
geotrees = geotrees[geotrees["Easting"] != 0]
geotrees = geotrees[geotrees["Northing"] != 0]
print(geotrees.shape)
# Out:
# (23388, 17)

# %%
# I used Maptolib to plot the trees on a map
import matplotlib.pyplot as plt

# I created a scatter plot of the trees based on their Easting and Northing values
plt.scatter(geotrees["Easting"], geotrees["Northing"])

# Added labels to the x and y axes
plt.xlabel("Easting")
plt.ylabel("Northing")

# Showed the plot
plt.show()

# %% [markdown]
# ### 7.3 Find Trees Outside Camden
# From the scatter plot, you should be able to determine how to select the rows from the trees data set containing the offending trees (using the Easting and Northing values)
#
# Select the rows containing trees outside of Camden.  Use the filter technique again.

# %%
# Selected the outlier rows
mask = geotrees['Northing'] > 194000

# %%
# Confirm how many rows we have
geotrees[mask].shape
# Out:
# (8, 17)

# %% [markdown]
# <hr/>
#
# ### 7.4 Observations

# %% [markdown]
# Using the scatter plot we could find trees that are not part of Candem and therefore we are able to delete them from the brochure

# %% [markdown]
# <hr/>

# %% [markdown]
# ## Task 8: Identify Unmatched Data
# We have multiple datasets that will need to be joined together to produce the analyses required by the Camden Parks and Open Spaces team.  The data will need to be joined in the following way:
#
# - Use the `Identifier` column in the trees dataset to match to the `Identifier` column in the environmental data set (so we can bring in the environmental data for each tree)
# - Use the `Scientific Name` column in the trees dataset to match to the `Scientific Name` column in the common names data set (so we can look up the `Common Name`)
#
# There may be mismatches in the data.  Of particular concern we want to check
#
# - That every tree in the trees dataset has matching environmental data in the environmental data set
# - That every environmental row in the environmental dataset has matching tree data in the tree data set
# - That every scientific name in the trees dataset has a matching common name in the common names data set
#
# We aren't too concerned about the reverse of the last scenario (if we have extra names in the common names dataset that aren't in the trees data set).  We don't expect Camden to have a specimen of every tree that exists!
#
# There are a few ways this can be done, but one technique is to use the `isin` function to check if some column in one dataframe contains values that are in another column in another dataframe.  This creates a mask containing rows that match between the two dataframes:
#
#     mask = df1['column_name1'].isin(df2['column_name2'])
#
# To select the non-matching rows, we can use Python's bitwise not operator ~:
#
#     mask = ~df1['column_name1'].isin(df2['column_name2'])
#
# As we have seen before, the mask can be used to select that subset of rows back from the original dataframe.

# %% [markdown]
# ### 8.1 Find Trees that Don't have Matching Environmental Data

# %%
# Find trees that don't have matching environmental data
mask = ~trees['Identifier'].isin(trees_cvs_file['Identifier'])
trees[mask]
# Out:
#       Identifier  Number Of Trees                                Site Name  \
# 66      00059712              1.0                       Maiden Lane Estate
# 125     00048578              1.0                              BUCK STREET
# 1148    00006577              1.0                              FAWLEY ROAD
# 1998    00007366              1.0        FORTUNE GREEN RD, OPEN SPACE (LS)
# 2246    00014633              1.0                          Mortimer Estate
# 5478    00060382              1.0                       SHAFTESBURY AVENUE
# 10637   00002874              1.0                            BURGHLEY ROAD
# 10977   00055227              1.0                            BURGHLEY ROAD
# 11795   00016702              1.0            RED LION SQUARE, GARDENS (LS)
# 11856   00054744              1.0          Carrol & Sanderson Close Estate
# 12056   00003694              1.0              Estate 1-161 Burnham (cons)
# 12936   00054558              1.0        ST. MARY'S KILBURN C OF E JMI (E)
# 13248   00059317              1.0                ADELAIDE ROAD NATURE AREA
# 16815   00055884              1.0                         HONEYBOURNE ROAD
# 18690   00059963              1.0                   Ampthill Square Estate
# 18958   00059246              1.0  Belsize nature reserve, Russell Nursery
# 19606   00005127              1.0       CUMBERLAND MARKET, OPEN SPACE (LS)
# 20169   00017912              1.0                            SHERRIFF ROAD
# 20226   00047080              1.0                   Ampthill Square Estate
# 21287   00029059              1.0         Estate 1-20 Marrick House (cons)
# 22470   00012126              1.0                       KINGS COLLEGE ROAD
# 23301   00010784              1.0                       Holly Lodge Estate
# 23315   00056485              1.0                       WATERLOW PARK (LS)
#
#       Contract Area                                    Scientific Name  \
# 66          Housing                                   Acer saccharinum
# 125        Highways                                   Sorbus aucuparia
# 1148       Highways                                     Tilia euchlora
# 1998          Parks                                    Ilex aquifolium
# 2246        Housing                                     Tilia europaea
# 5478       Highways                                    Vacant Tree Pit
# 10637      Highways                               Platanus x hispanica
# 10977      Highways                              Amelanchier lamarckii
# 11795         Parks                               Platanus x hispanica
# 11856       Housing                        Prunus unidentified species
# 12056       Housing                                   Acer platanoides
# 12936     Education                              Amelanchier lamarckii
# 13248         Parks                                         Stump Only
# 16815      Highways                     Acer pseudoplatanus 'Brilliant
# 18690       Housing  Vacant Tree Pit (planned: Parrotia persica van...
# 18958         Parks                                      Ulmus procera
# 19606         Parks                               Platanus x hispanica
# 20169      Highways                                 Tilia platyphyllos
# 20226       Housing                         Malus unidentified species
# 21287       Housing                                     Sambucus nigra
# 22470      Highways                                 Fraxinus excelsior
# 23301       Housing                                    Ilex aquifolium
# 23315         Parks                                 Fraxinus excelsior
#
#       Inspection Date Inspection Due Date  Height In Metres  Spread In Metres  \
# 66         2019-05-28           2022/2023              12.0               5.0
# 125        2017-07-19           2020/2021               6.0               2.0
# 1148       2018-09-28           2021/2022              15.0               6.0
# 1998       2017-03-21           2019/2020               9.0               6.0
# 2246       2019-01-29           2021/2022              16.0              12.0
# 5478              NaT                 NaN               NaN               NaN
# 10637      2017-08-14           2020/2021              20.0               8.0
# 10977      2017-08-14           2020/2021               3.0               2.0
# 11795      2018-06-04           2021/2022              30.0              23.0
# 11856      2017-01-06           2020/2021               3.0               3.0
# 12056      2018-04-17           2021/2022               3.0               1.0
# 12936      2019-10-07           2022/2023               4.0               2.0
# 13248      2019-01-31           2021/2022               0.0               5.0
# 16815      2018-05-10           2021/2022               2.0               1.0
# 18690      2019-01-08           2022/2023               NaN               NaN
# 18958      2019-01-29           2021/2022               5.0               4.0
# 19606      2018-03-13           2020/2021              10.0               8.0
# 20169      2018-10-09           2021/2022               9.0               5.0
# 20226      2019-01-08           2022/2023               5.0               3.0
# 21287      2018-06-19           2021/2022               6.0               6.0
# 22470      2018-07-13           2021/2022              18.0              12.0
# 23301      2017-06-14           2020/2021               7.0               5.0
# 23315      2019-05-24           2022/2023              12.0               5.0
#
#        Diameter In Centimetres At Breast Height  Ward Code  \
# 66                                         20.0  E05000131
# 125                                        10.0  E05000130
# 1148                                       38.0  E05000145
# 1998                                       44.0  E05000132
# 2246                                       47.0  E05000140
# 5478                                        NaN  E05000138
# 10637                                      52.0  E05000139
# 10977                                       5.0  E05000139
# 11795                                     165.0  E05000138
# 11856                                      13.0  E05000137
# 12056                                       6.0  E05000128
# 12936                                       8.0  E05000140
# 13248                                      50.0  E05000128
# 16815                                       4.0  E05000145
# 18690                                       NaN  E05000143
# 18958                                      11.0  E05000134
# 19606                                      38.0  E05000142
# 20169                                      42.0  E05000145
# 20226                                      16.0  E05000143
# 21287                                      39.0  E05000140
# 22470                                      48.0  E05000128
# 23301                                      20.0  E05000137
# 23315                                      16.0  E05000137
#
#                             Ward Name  Easting  Northing  Longitude  \
# 66                         Cantelowes   529795    184142  -0.129750
# 125    Camden Town with Primrose Hill   528900    184020  -0.142698
# 1148                   West Hampstead   525572    185015  -0.190313
# 1998                    Fortune Green   525074    185541  -0.197304
# 2246                          Kilburn   525763    183613  -0.188060
# 5478        Holborn and Covent Garden   530073    181247  -0.126813
# 10637                    Kentish Town   529119    185889  -0.138863
# 10977                    Kentish Town   528920    185694  -0.141802
# 11795       Holborn and Covent Garden   530572    181701  -0.119460
# 11856                        Highgate   528661    185556  -0.145585
# 12056                         Belsize   527015    184315  -0.169763
# 12936                         Kilburn   525443    183919  -0.192552
# 13248                         Belsize   527577    184297  -0.161664
# 16815                  West Hampstead   525593    185050  -0.189987
# 18690      St Pancras and Somers Town   529216    183103  -0.138479
# 18958                      Gospel Oak   527523    185233  -0.162101
# 19606                   Regent's Park   528913    182814  -0.142959
# 20169                  West Hampstead   525265    184543  -0.194897
# 20226      St Pancras and Somers Town   529279    183106  -0.137573
# 21287                         Kilburn   525832    183583  -0.187075
# 22470                         Belsize   526999    184416  -0.169957
# 23301                        Highgate   528472    186812  -0.147845
# 23315                        Highgate   528730    187264  -0.143955
#
#         Latitude                Location
# 66     51.541266   (51.541266, -0.12975)
# 125    51.540371  (51.540371, -0.142698)
# 1148   51.550062  (51.550062, -0.190313)
# 1998   51.554901  (51.554901, -0.197304)
# 2246   51.537424   (51.537424, -0.18806)
# 5478   51.515186  (51.515186, -0.126813)
# 10637  51.557120   (51.55712, -0.138863)
# 10977  51.555408  (51.555408, -0.141802)
# 11795  51.519146   (51.519146, -0.11946)
# 11856  51.554226  (51.554226, -0.145585)
# 12056  51.543451  (51.543451, -0.169763)
# 12936  51.540245  (51.540245, -0.192552)
# 13248  51.543163  (51.543163, -0.161664)
# 16815  51.550377  (51.550377, -0.189987)
# 18690  51.532058  (51.532058, -0.138479)
# 18958  51.551587  (51.551587, -0.162101)
# 19606  51.529527  (51.529527, -0.142959)
# 20169  51.545886  (51.545886, -0.194897)
# 20226  51.532073  (51.532073, -0.137573)
# 21287  51.537139  (51.537139, -0.187075)
# 22470  51.544363  (51.544363, -0.169957)
# 23301  51.565562  (51.565562, -0.147845)
# 23315  51.569567  (51.569567, -0.143955)

# %%
# Confirm how many rows we have
trees[mask].shape
# Out:
# (23, 17)

# %% [markdown]
# ### 8.2 Find Environmental Data that Doesn't have Matching Tree Data

# %%
# Find environmental data that doesn't have matching tree data
mask = ~trees.isin(trees_cvs_file)
trees[mask]
# Out:
#       Identifier  Number Of Trees                         Site Name  \
# 0       00060053              1.0          Russell Nurseries Estate
# 1       00057855              1.0                 BRECKNOCK JMI (E)
# 2       00059953              1.0        Estate 51 Ravenshaw Street
# 3       00059915              1.0                 ROSARY RC JMI (E)
# 4       00010762              1.0                Holly Lodge Estate
# ...          ...              ...                               ...
# 23439   00057455              1.0  KILBURN GRANGE, MESSINA AVE (LS)
# 23440   00015494              1.0                  OSSULSTON STREET
# 23441   00001693              1.0                    BELMONT STREET
# 23442   00020342              1.0              Templar House Estate
# 23443   00013369              1.0                    LYNDHURST ROAD
#
#       Contract Area          Scientific Name Inspection Date  \
# 0           Housing          Vacant Tree Pit             NaT
# 1         Education          Vacant Tree Pit      2019-07-17
# 2           Housing             Ficus carica             NaT
# 3         Education      Betula jacquemontii             NaT
# 4           Housing     Ilex x altaclarensis      2017-06-14
# ...             ...                      ...             ...
# 23439         Parks              Sorbus aria      2017-03-28
# 23440      Highways  Sorbus aria 'Majestica'      2019-10-28
# 23441      Highways     Platanus x hispanica      2017-07-31
# 23442       Housing           Tilia europaea      2018-11-05
# 23443      Highways           Tilia europaea      2018-06-08
#
#       Inspection Due Date  Height In Metres  Spread In Metres  \
# 0                     NaN               NaN               NaN
# 1               2022/2023               NaN               NaN
# 2                     NaN               5.0               4.0
# 3                     NaN               4.0               1.0
# 4               2020/2021              14.0               6.0
# ...                   ...               ...               ...
# 23439           2019/2020               2.0               1.0
# 23440           2022/2023              12.0               6.0
# 23441           2020/2021              18.0              10.0
# 23442           2021/2022              20.0               8.0
# 23443           2021/2022              15.0               6.0
#
#        Diameter In Centimetres At Breast Height  Ward Code  \
# 0                                           NaN  E05000135
# 1                                           NaN  E05000131
# 2                                          10.0        NaN
# 3                                           6.0  E05000135
# 4                                          26.0  E05000137
# ...                                         ...        ...
# 23439                                       6.0  E05000140
# 23440                                      48.0  E05000143
# 23441                                      57.0  E05000136
# 23442                                      40.0  E05000132
# 23443                                      77.0  E05000135
#
#                         Ward Name  Easting  Northing  Longitude   Latitude  \
# 0                  Hampstead Town   527305    185240  -0.165240  51.551693
# 1                      Cantelowes   529923    184782  -0.127681  51.546984
# 2                             NaN        0         0        NaN        NaN
# 3                  Hampstead Town   527249    185261  -0.166051  51.551901
# 4                        Highgate   528414    186770  -0.148704  51.565198
# ...                           ...      ...       ...        ...        ...
# 23439                     Kilburn   525130    184418  -0.196884  51.544796
# 23440  St Pancras and Somers Town   529758    183095  -0.130667  51.531863
# 23441                  Haverstock   528302    184457  -0.151163  51.544432
# 23442               Fortune Green   524615    184714  -0.204206  51.547573
# 23443              Hampstead Town   526738    185304  -0.173397  51.552397
#
#                      Location
# 0       (51.551693, -0.16524)
# 1      (51.546984, -0.127681)
# 2                         NaN
# 3      (51.551901, -0.166051)
# 4      (51.565198, -0.148704)
# ...                       ...
# 23439  (51.544796, -0.196884)
# 23440  (51.531863, -0.130667)
# 23441  (51.544432, -0.151163)
# 23442  (51.547573, -0.204206)
# 23443  (51.552397, -0.173397)
#
# [23444 rows x 17 columns]

# %%
# Confirm how many rows we have
trees[mask].shape
# Out:
# (23444, 17)

# %% [markdown]
# ### 8.3 Find Trees that Don't have Matching Common Names Data

# %%
# Find trees with scientific names that don't have matching common names data
mask = ~trees['Scientific Name'].isin(tree_json['Scientific Name'])
trees[mask]
# Out:
#       Identifier  Number Of Trees                             Site Name  \
# 151     00051832              1.0                           ARGYLE WALK
# 384     00053954              1.0                        CHURCHILL ROAD
# 495     00047497              1.0                        PATSHULL PLACE
# 611     00055434              1.0                  SHARPLES HALL STREET
# 653     00055289              1.0                      QUEEN'S CRESCENT
# ...          ...              ...                                   ...
# 21826   00050835              1.0                           INGESTRE RD
# 22948   00052341              1.0                    NEW COMPTON STREET
# 23266   00048846              1.0                           ASMARA ROAD
# 23335   00048705              1.0                     GOLDINGTON STREET
# 23372   00031627              1.0  ST. GEORGE THE MARTYR C OF E JMI (E)
#
#       Contract Area                Scientific Name Inspection Date  \
# 151        Highways  Sorbus aucuparia 'Streetwise'      2019-02-10
# 384        Highways  Sorbus aucuparia 'Streetwise'      2017-10-07
# 495        Highways  Sorbus aucuparia 'Streetwise'      2017-06-22
# 611        Highways  Sorbus aucuparia 'Streetwise'      2019-09-30
# 653        Highways  Sorbus aucuparia 'Streetwise'      2017-07-08
# ...             ...                            ...             ...
# 21826      Highways  Sorbus aucuparia 'Streetwise'      2017-08-18
# 22948      Highways  Sorbus aucuparia 'Streetwise'      2019-07-08
# 23266      Highways  Sorbus aucuparia 'Streetwise'      2018-08-28
# 23335      Highways  Sorbus aucuparia 'Streetwise'      2019-10-23
# 23372     Education       Cotoneaster salicifolius      2018-07-23
#
#       Inspection Due Date  Height In Metres  Spread In Metres  \
# 151             2022/2023               7.0               3.0
# 384             2020/2021               3.0               2.0
# 495             2020/2021               5.0               3.0
# 611             2022/2023               2.0               2.0
# 653             2020/2021               4.0               1.0
# ...                   ...               ...               ...
# 21826           2020/2021               3.0               1.0
# 22948           2022/2023               4.0               3.0
# 23266           2021/2022               5.0               3.0
# 23335           2022/2023               6.0               2.0
# 23372           2021/2022               5.0               5.0
#
#        Diameter In Centimetres At Breast Height  Ward Code  \
# 151                                        12.0  E05000141
# 384                                         5.0  E05000139
# 495                                        11.0  E05000131
# 611                                         4.0  E05000130
# 653                                         7.0  E05000136
# ...                                         ...        ...
# 21826                                       7.0  E05000139
# 22948                                       6.0  E05000138
# 23266                                       8.0  E05000132
# 23335                                      12.0  E05000143
# 23372                                       8.0  E05000138
#
#                             Ward Name  Easting  Northing  Longitude  \
# 151                      King's Cross   530227    182706  -0.124054
# 384                      Kentish Town   529007    185975  -0.140440
# 495                        Cantelowes   529202    184717  -0.138094
# 611    Camden Town with Primrose Hill   527962    184050  -0.156202
# 653                        Haverstock   528072    184723  -0.154369
# ...                               ...      ...       ...        ...
# 21826                    Kentish Town   528962    185826  -0.141137
# 22948       Holborn and Covent Garden   529976    181160  -0.128249
# 23266                   Fortune Green   524568    185347  -0.204661
# 23335      St Pancras and Somers Town   529662    183417  -0.131941
# 23372       Holborn and Covent Garden   530742    182119  -0.116856
#
#         Latitude                Location
# 151    51.528257  (51.528257, -0.124054)
# 384    51.557913   (51.557913, -0.14044)
# 495    51.546569  (51.546569, -0.138094)
# 611    51.540853  (51.540853, -0.156202)
# 653    51.546881  (51.546881, -0.154369)
# ...          ...                     ...
# 21826  51.556589  (51.556589, -0.141137)
# 22948  51.514422  (51.514422, -0.128249)
# 23266  51.553268  (51.553268, -0.204661)
# 23335  51.534780   (51.53478, -0.131941)
# 23372  51.522865  (51.522865, -0.116856)
#
# [76 rows x 17 columns]

# %%
# Confirm how many rows we have
trees[mask].shape
# Out:
# (76, 17)

# %% [markdown]
# <hr/>
#
# ### 8.4 Observations

# %% [markdown]
# There are 23 trees that don't have matching environmental data.
# There are 76 trees that don't have matching common names data.
# This would make it difficult to be able to produce all three requirements, as the common names would be incompltete for the Public Tree Data, the map would be incomplete for the trees brochure and were missing matching data from common names to enviromental, which would affect the environmental report.

# %% [markdown]
# <hr/>

# %% [markdown]
# # END OF NOTEBOOK
